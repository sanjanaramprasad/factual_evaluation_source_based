# %%
import pandas as pd

# %%
df = pd.read_csv('/home/sanjana/factual_evaluation_source_based/datasets/sota_annotations/dialogue_aggrefact.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     DocID                                           Dialogue  \
# 0           0  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 1           1  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 2           2  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 3           3  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 4           4  13809941  Thelma: i dont have anything to wear\nLouisa: ...
#
#                   Model                                            Summary  \
# 0             human_ref      Louisa will lend Thelma her red velvet dress.
# 1            bart_large  Thelma doesn't have anything to wear. Louisa w...
# 2         mv-bart_large  Thelma doesn't have anything to wear. Louisa w...
# 3     co-ref bart large  Thelma doesn't have anything to wear. Louisa w...
# 4  condigsum bart large     Louisa will bring Thelma her red velvet dress.
#
# ...

# %%
for idx, row in df[~df['CircE_text'].isnull()].iterrows():
    print(row['Dialogue'])
    # print('---')
    print('\nSUMMARY', row['Summary'])
    print('\nTEXT', row['CircE_text'])
    print('***'*13)
# Out:
# #Person1#: How can we get in touch with you?
# #Person2#: Please call me or send e-mail. Could you please let me know when your organization can make a decision?
# #Person1#: About one week.
# #Person2#: I really appreciate your time and help. See you then.
#
# SUMMARY #Person2# asks #Person1# to contact #Person2# when #Person2#'s organization can make a decision.
#
# TEXT #
# ***************************************
# #Person1#: What else, Ma'am?
# #Person2#: No, thanks. My husband said, We'd like to pay now.
# #Person1#: Let me show you to the cashier's. It's 905 yuan in total.
# #Person2#: What? Where does that five come from?
# #Person1#: Oh, it's a service charge.
# #Person2#: But I only have 900 in cash here. Can you let it go for 900 yuan?
# #Person1#: Sorry, but we can't do that. It's store's rule.
# #Person2#: My husband said he had a credit card. Do you accept credit card?
# #Person1#: Yes.
# #Person2#: Great. Here it is.
# ...
