# %%
import psycopg2
import pandas as pd
import sqlalchemy

# %%
db_engine = sqlalchemy.create_engine('postgresql://sgqokpuggkrkve:ff59f8ca03f950cef2e98fb4ae4ff44bdf7136ff37da62215672902c613297d6@ec2-18-211-172-50.compute-1.amazonaws.com:5432/d3mhp3r7jhume9')

# %%
df = pd.read_sql_query('select * from "label"',con=db_engine)

# %%
len(df)
# Out:
# 71

# %%
df.to_csv('/home/sanjana/factual_evaluation_source_based/datasets/llm_annotations/sample/sample_annotations_sanjana.csv')

# %%
df_errors = df[~df['error_type'].isnull()]

# %%
len(df_errors)
# Out:
# 17

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def get_pos(text):
    doc = nlp(text)
    tokens = []
    for token in doc:
        tokens+= [(token.text, token.dep_, token.tag_)]
    return tokens
# Out:
# /opt/conda/envs/eval_env/lib/python3.8/site-packages/spacy/util.py:887: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.5.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
df_errors['pos_tags'] = [get_pos(text) for text in df_errors['summary'].values]
# Out:
# /tmp/ipykernel_21180/3487107618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_errors['pos_tags'] = [get_pos(text) for text in df_errors['summary'].values]

# %%
df_errors
# Out:
#                                     uuid  user_id       docid          model  \
# 6   e5b713fb-3e7e-46c9-bf74-d54b5ad7aa96  sanjana    13611734  gpt4-32k-0613
# 7   1632add2-b82d-4404-8d0e-d30ed74e6ec9  sanjana    13611734  gpt4-32k-0613
# 10  518f1abd-f108-4df9-b8f2-7a4493ee917b  sanjana  13611884-1  gpt4-32k-0613
# 12  d612c933-1fa1-49b5-a24c-cc936c4cc5ec  sanjana    13680873  gpt4-32k-0613
# 13  0e251ef7-f3cb-4e14-82c3-565a94703037  sanjana    13680968  gpt4-32k-0613
# 36  3db1d56f-7cb9-4b23-9c8c-3e1f401d42cd  sanjana    13681482  gpt4-32k-0613
# 40  6ad7267d-d27a-4600-9b3d-93f6f9037020  sanjana    13681886  gpt4-32k-0613
# 41  9ae77f56-8e7b-4e91-b5e5-a33e8e5bde40  sanjana    13682217  gpt4-32k-0613
# 47  0f5413eb-0c8d-4a2b-8bb8-496a4c12ac22  sanjana    13682408  gpt4-32k-0613
# 56  947a7901-a419-4664-b0c6-e107e116a5b2  sanjana    13716518  gpt4-32k-0613
# 58  fbfb5dab-fe6a-40a7-94d1-8b5cd55d7890  sanjana    13716726  gpt4-32k-0613
# 59  5d4a3b8d-818c-4acd-a656-5883c10d55b9  sanjana    13716595  gpt4-32k-0613
# 60  e1bae834-c764-44ac-be23-a4d77be2c776  sanjana    13716595  gpt4-32k-0613
# 61  86b33373-2120-4cc8-80dc-66e3a247f481  sanjana    13716726  gpt4-32k-0613
# 64  8b617613-cdbe-4161-afea-f37037d1a945  sanjana    13717284  gpt4-32k-0613
# 65  b4e38fed-94fb-42ed-a970-eefbd4cfe9e9  sanjana    13727579  gpt4-32k-0613
# 68  8bcab26d-78e0-46ae-89dd-3c4a7ac52039  sanjana    13716905  gpt4-32k-0613
#
#                                      nonfactual_spans  \
# 6                      performance of a soccer player
# 7                                        on the pitch
# 10                   including boots and warm jackets
# 12                   their mutual acquaintance, Aaron
# 13            Boris reminds her to initial the change
# 36                                Filip wasn't around
# 40  She is concerned about possibly spreading the ...
# 41   programming language she's been learning for ...
# 47  they decide through a card pack which animal t...
# 56   Laura initially mentions she received no replies
# 58   Shanon, Victor, Oliver, and Sid, express thei...
# 59                urging participants to take it easy
# 60                urging participants to take it easy
# 61  Shanon, Victor, Oliver, and Sid, express their...
# 64  Terry, who ended up quitting due to stress-rel...
# 65              agreeing to prepare some food for him
# 68       family photo taken during a cousin's wedding
#
#                                              evidence       error_type  \
# 6                                           Not found  Extrinsic_Error
# 7                                           Not found  Extrinsic_Error
# 10  Nathan: : No, I explained to her that he'll be...  Intrinsic_Error
# 12                                          Not found  Extrinsic_Error
# 13  Sarah: : Do I need to initial the change?\nBor...  Intrinsic_Error
# 36  Derek : McCarthy: Filip - are you around? Woul...  Intrinsic_Error
# 40  Stella: : I wanted to come and visit you but I...  Intrinsic_Error
# 41  Agata: : Sorry. After just one month of coding...  Intrinsic_Error
# 47  Sophie: : you will have to tell me about the f...  Intrinsic_Error
# 56  Sarah: : omg Laura! sorry you didn't get any r...  Intrinsic_Error
# 58  Shanon: : Yeah. So what bout him?\nShanon: : B...  Intrinsic_Error
# 59                          Atnee: : Ed, take it easy  Intrinsic_Error
# 60                          Atnee: : Ed, take it easy  Intrinsic_Error
# 61  Shanon: : Yeah. So what bout him?\nVictor: : H...  Intrinsic_Error
# 64  Tim: : Quit eventually, but he had trouble sle...  Intrinsic_Error
# 65             Mum: : I'll wrap something up for you.  Intrinsic_Error
# 68  Chiara: : It's us in Chicago 2 weeks ago.\nLuc...  Intrinsic_Error
#
#                                               summary  \
# 6   Richie and Clay are discussing the performance...
# 7   Richie and Clay are discussing the performance...
# 10  Nathan and Deborah are planning a family trip ...
# 12  Darcy asked Adam if he had ever been to Egypt ...
# 13  Sarah''s request for PTO was denied due to man...
# 36  Derek McCarthy asked if he could borrow an And...
# 40  Stella, a teacher, reaches out to her friend S...
# 41  Guido reaches out to Agata because he doesn''t...
# 47  Jenkin and Sophie discuss their respective spi...
# 56  The dialogue features Sarah, Laura, and Raf. L...
# 58  The group of students, Shanon, Victor, Oliver,...
# 59  Ed, Valerie, and Jessica emphasized traditiona...
# 60  Ed, Valerie, and Jessica emphasized traditiona...
# 61  The group of students, Shanon, Victor, Oliver,...
# 64  Joe expresses feeling overwhelmed by his job, ...
# 65  Steve expressed to his Mum that he was very hu...
# 68  Yvonne and Chiara, two nieces, inquire about t...
#
#                                              dialogue  \
# 6   Richie: Pogba\r\nClay: Pogboom\r\nRichie: what...
# 7   Richie: Pogba\r\nClay: Pogboom\r\nRichie: what...
# 10  Nathan: Hey Honey, what are our plans for tomo...
# 12  Darcy: have you ever been to Egypt?\r\nAdam: w...
# 13  Boris: Due to the number of PTO requests this ...
# 36  Derek McCarthy: Filip - are you around? Would ...
# 40  Stella: Hi Sandra\r\nStella: Did you recover f...
# 41  Guido: Hi, Agata, are you OK?\r\nAgata: Hi, Gu...
# 47  Jenkin: hey what is your spirit animal?\r\nSop...
# 56  Sarah: omg Laura! sorry you didn''t get any re...
# 58  Shanon: Yeah. So what bout him?\r\nVictor: He'...
# 59  Ed: Sinners!! Sex is for married people\r\nVal...
# 60  Ed: Sinners!! Sex is for married people\r\nVal...
# 61  Shanon: Yeah. So what bout him?\r\nVictor: He'...
# 64  Joe: This job is wearing me up\r\nTim: Oh no! ...
# 65  Mum: hungry?\r\nSteve: starving...\r\nMum: I''...
# 68  Yvonne: How''s uncle Sam?\r\nLucy: He''s OK, j...
#
#                                              pos_tags
# 6   [(Richie, nsubj, NNP), (and, cc, CC), (Clay, c...
# 7   [(Richie, nsubj, NNP), (and, cc, CC), (Clay, c...
# 10  [(Nathan, nsubj, NNP), (and, cc, CC), (Deborah...
# 12  [(Darcy, nsubj, NNP), (asked, ROOT, VBD), (Ada...
# 13  [(Sarah, poss, NNP), (', case, POS), ('s, case...
# 36  [(Derek, compound, NNP), (McCarthy, nsubj, NNP...
# 40  [(Stella, nsubj, NNP), (,, punct, ,), (a, det,...
# 41  [(Guido, nsubj, NNP), (reaches, ROOT, VBZ), (o...
# 47  [(Jenkin, nsubj, NNP), (and, cc, CC), (Sophie,...
# 56  [(The, det, DT), (dialogue, nsubj, NN), (featu...
# 58  [(The, det, DT), (group, nsubj, NN), (of, prep...
# 59  [(Ed, npadvmod, NNP), (,, punct, ,), (Valerie,...
# 60  [(Ed, npadvmod, NNP), (,, punct, ,), (Valerie,...
# 61  [(The, det, DT), (group, nsubj, NN), (of, prep...
# 64  [(Joe, nsubj, NNP), (expresses, ROOT, VBZ), (f...
# 65  [(Steve, nsubj, NNP), (expressed, ROOT, VBD), ...
# 68  [(Yvonne, nsubj, NNP), (and, cc, CC), (Chiara,...

# %%
df_errors.iloc[[2]]['pos_tags'].values[0]
# Out:
# [('Nathan', 'nsubj', 'NNP'),
#  ('and', 'cc', 'CC'),
#  ('Deborah', 'conj', 'NNP'),
#  ('are', 'aux', 'VBP'),
#  ('planning', 'ROOT', 'VBG'),
#  ('a', 'det', 'DT'),
#  ('family', 'compound', 'NN'),
#  ('trip', 'dobj', 'NN'),
#  ('and', 'cc', 'CC'),
#  ('decide', 'conj', 'VB'),
#  ('to', 'aux', 'TO'),
#  ('pack', 'xcomp', 'VB'),
#  ('everything', 'dobj', 'NN'),
#  ('a', 'det', 'DT'),
#  ('day', 'npadvmod', 'NN'),
#  ('ahead', 'advmod', 'RB'),
#  ('.', 'punct', '.'),
#  ("They''re", 'ROOT', 'NN'),
#  ('considering', 'acl', 'VBG'),
#  ('the', 'det', 'DT'),
#  ('space', 'dobj', 'NN'),
#  ('required', 'acl', 'VBN'),
#  ('in', 'prep', 'IN'),
#  ('the', 'det', 'DT'),
#  ('car', 'pobj', 'NN'),
#  ('for', 'prep', 'IN'),
#  ('their', 'poss', 'PRP$'),
#  ('daughters', 'poss', 'NNS'),
#  ("''", 'case', "''"),
#  ('items', 'pobj', 'NNS'),
#  (',', 'punct', ','),
#  ('including', 'prep', 'VBG'),
#  ('boots', 'pobj', 'NNS'),
#  ('and', 'cc', 'CC'),
#  ('warm', 'amod', 'JJ'),
#  ('jackets', 'conj', 'NNS'),
#  ('.', 'punct', '.'),
#  ('They', 'nsubj', 'PRP'),
#  ('plan', 'ROOT', 'VBP'),
#  ('to', 'aux', 'TO'),
#  ('bring', 'xcomp', 'VB'),
#  ('bicycles', 'dobj', 'NNS'),
#  ('for', 'prep', 'IN'),
#  ('some', 'det', 'DT'),
#  ('alone', 'amod', 'JJ'),
#  ('time', 'pobj', 'NN'),
#  ('while', 'mark', 'IN'),
#  ('the', 'det', 'DT'),
#  ('rest', 'advcl', 'NN'),
#  ('of', 'prep', 'IN'),
#  ('the', 'det', 'DT'),
#  ('family', 'compound', 'NN'),
#  ('hikes', 'pobj', 'VBZ'),
#  ('.', 'punct', '.'),
#  ('Nathan', 'nsubj', 'NNP'),
#  ('has', 'ROOT', 'VBZ'),
#  ('a', 'det', 'DT'),
#  ('dentist', 'amod', 'JJ'),
#  ('appointment', 'dobj', 'NN'),
#  ('after', 'prep', 'IN'),
#  ('work', 'pcomp', 'NN'),
#  ('the', 'det', 'DT'),
#  ('next', 'amod', 'JJ'),
#  ('day', 'npadvmod', 'NN'),
#  ('and', 'cc', 'CC'),
#  ('will', 'aux', 'MD'),
#  ('pick', 'conj', 'VB'),
#  ('up', 'prt', 'RP'),
#  ('travel', 'compound', 'NN'),
#  ('sickness', 'compound', 'NN'),
#  ('syrup', 'dobj', 'NN'),
#  ('while', 'mark', 'IN'),
#  ('Deborah', 'nsubj', 'NNP'),
#  ('picks', 'advcl', 'VBZ'),
#  ('up', 'prt', 'RP'),
#  ('their', 'poss', 'PRP$'),
#  ('daughters', 'dobj', 'NNS'),
#  ('from', 'prep', 'IN'),
#  ('school', 'pobj', 'NN'),
#  ('.', 'punct', '.'),
#  ('They', 'nsubj', 'PRP'),
#  ('plan', 'ROOT', 'VBP'),
#  ('to', 'aux', 'TO'),
#  ('leave', 'xcomp', 'VB'),
#  ('for', 'prep', 'IN'),
#  ('their', 'poss', 'PRP$'),
#  ('trip', 'pobj', 'NN'),
#  ('after', 'prep', 'IN'),
#  ('a', 'det', 'DT'),
#  ('quick', 'amod', 'JJ'),
#  ('meal', 'pobj', 'NN'),
#  ('at', 'prep', 'IN'),
#  ('home', 'pobj', 'NN'),
#  ('.', 'punct', '.')]

# %%
df_errors.to_csv('sanjana_df_aggr_sample_errors.csv')
