# %%
import pandas as pd

# %%
df_transformer = pd.read_csv('/home/sanjana/factual_evaluation_source_based/datasets/sota_annotations/dialogue_aggrefact.csv')
df_llms_annot1 = pd.read_csv('/home/sanjana/factual_evaluation_source_based/annotations/sample/sample_annotations_sanjana.csv')
df_llms_annot1.head()
# Out:
#    Unnamed: 0                                  uuid  user_id     docid model  \
# 0           0  c5b1509d-b628-4b95-9d46-39d6d09a8738  sanjana   test_12  GPT4
# 1           1  b8b918d6-e42d-4227-bab2-d82595e1586b  sanjana  test_120  GPT4
# 2           2  5bbedec9-91e7-4fc9-9ed7-266d47bd9dae  sanjana  test_123  GPT4
# 3           3  597724f2-6d56-4ebc-9e07-123beec157ae  sanjana  test_127  GPT4
# 4           4  b094ce58-5993-44a7-ab7e-c870f15f255d  sanjana  test_132  GPT4
#
#   nonfactual_spans evidence error_type  \
# 0              NaN      NaN        NaN
# 1              NaN      NaN        NaN
# 2              NaN      NaN        NaN
# 3              NaN      NaN        NaN
# 4              NaN      NaN        NaN
#
#                                              summary  \
# 0  Person 1 (Steven) noticed that Person 2 (Tony)...
# 1  Person1 checks if Person2 has fed the puppies,...
# 2  Person1 inquires about the method to contact P...
# 3  Person1 asked Mr. Smith (Person2) about his ed...
# 4  Person1 and Person2 discuss their idea of the ...
#
#                                             dialogue
# 0  #Person1#: Hi, Tony. You look unhappy. What''s...
# 1  #Person1#: Have you given the puppies food yet...
# 2  #Person1#: How can we get in touch with you?\r...
# 3  #Person1#: Could you tell me what university y...
# 4  #Person1#: Hey Rocky! You''ve been sitting aro...

# %%
df_llms_annot2 = pd.read_csv('/home/sanjana/factual_evaluation_source_based/annotations/sample/sample_annotations_elisa.csv')

df_llms_annot2.head()
# Out:
#    Unnamed: 0  uuid user_id     docid model  \
# 0           0     6   elisa   test_12  GPT4
# 1           1     7   elisa  test_120  GPT4
# 2           2     8   elisa  test_123  GPT4
# 3           3     9   elisa  test_127  GPT4
# 4           4    10   elisa  test_127  GPT4
#
#                     nonfactual_spans      evidence       error_type  \
# 0  Person 1 (Steven) noticed that Pe  What happene  Intrinsic_Error
# 1                                NaN           NaN              NaN
# 2      Person1 inquires about the me           NaN  Intrinsic_Error
# 3                 Person1 asked Mr.            NaN  Intrinsic_Error
# 4              s, and earned a weekl           NaN  Intrinsic_Error
#
#                                              summary  \
# 0  Person 1 (Steven) noticed that Person 2 (Tony)...
# 1  Person1 checks if Person2 has fed the puppies,...
# 2  Person1 inquires about the method to contact P...
# 3  Person1 asked Mr. Smith (Person2) about his ed...
# 4  Person1 asked Mr. Smith (Person2) about his ed...
#
#                                             dialogue
# 0  #Person1#: Hi, Tony. You look unhappy. What's ...
# 1  #Person1#: Have you given the puppies food yet...
# 2  #Person1#: How can we get in touch with you?\r...
# 3  #Person1#: Could you tell me what university y...
# 4  #Person1#: Could you tell me what university y...

# %%
import math 
agreement_count = 0

# len(set(df_llms_annot1['docid'].values)), len(set(df_llms_annot2['docid'].values))
for docid in set(df_llms_annot1['docid'].values:
    ann1_row = df_llms_annot1[df_llms_annot1['docid'] == doc_id]
    ann2_row = df_llms_annot2[df_llms_annot2['docid'] == doc_id]
# for idx, row in df_llms_annot2.iterrows():
#     # print(idx)
#     doc_id = row['docid']
#     error_type_2 = row['error_type']
#     error_type_2 = '' if type(error_type_2) is not str else error_type_2
#     error_type_1 =  df_llms_annot1[df_llms_annot1['docid'] == doc_id]['error_type'].values[0]
#     error_type_1 = '' if type(error_type_1) is not str else error_type_1
    
#     if error_type_1 == error_type_2:
#         # print(error_type_2, error_type_1)
#         agreement_count += 1
# agreement_count/len(df_llms_annot2)
# Out:
# (74, 74)

# %%
df_transformer
error_key = 'w/ Error'
error_key = 'error_type'
error_vals = [1]
# df_errors = df[df[error_key].isin(error_val)]
# df = {'
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
sns.histplot(data=df_llms, x=error_key)
plt.show()

# %%
df_llms
# Out:
#     Unnamed: 0                                  uuid  user_id     docid model  \
# 0            0  c5b1509d-b628-4b95-9d46-39d6d09a8738  sanjana   test_12  GPT4
# 1            1  b8b918d6-e42d-4227-bab2-d82595e1586b  sanjana  test_120  GPT4
# 2            2  5bbedec9-91e7-4fc9-9ed7-266d47bd9dae  sanjana  test_123  GPT4
# 3            3  597724f2-6d56-4ebc-9e07-123beec157ae  sanjana  test_127  GPT4
# 4            4  b094ce58-5993-44a7-ab7e-c870f15f255d  sanjana  test_132  GPT4
# ..         ...                                   ...      ...       ...   ...
# 70          70  e16a9555-6c3a-4bb0-baee-37139046e585  sanjana  test_376  GPT4
# 71          71  eb5ba863-59fe-4ba7-bd01-866addbabb61  sanjana  test_360  GPT4
# 72          72  dde9a945-7665-4399-b2e5-2e67c885b8c5  sanjana  test_364  GPT4
# 73          73  6334afa6-8f3b-48c1-a85d-6b065d61315b  sanjana  test_372  GPT4
# 74          74  91174d8e-6d6e-4936-8862-53eecebbb311  sanjana  test_373  GPT4
#
#    nonfactual_spans evidence error_type  \
# 0               NaN      NaN        NaN
# 1               NaN      NaN        NaN
# 2               NaN      NaN        NaN
# 3               NaN      NaN        NaN
# 4               NaN      NaN        NaN
# ..              ...      ...        ...
# 70              NaN      NaN        NaN
# 71              NaN      NaN        NaN
# 72              NaN      NaN        NaN
# 73              NaN      NaN        NaN
# 74              NaN      NaN        NaN
#
#                                               summary  \
# 0   Person 1 (Steven) noticed that Person 2 (Tony)...
# 1   Person1 checks if Person2 has fed the puppies,...
# 2   Person1 inquires about the method to contact P...
# 3   Person1 asked Mr. Smith (Person2) about his ed...
# 4   Person1 and Person2 discuss their idea of the ...
# ..                                                ...
# 70  Person1 and Person2 discussed the possibility ...
# 71  Person1 came back to their seats with hot dogs...
# 72  Person2 approached Person1 to return a book an...
# 73  Person1 seeks advice from Person2 about inquir...
# 74  Person1 and Person2 toured around Person2''s h...
#
#                                              dialogue
# 0   #Person1#: Hi, Tony. You look unhappy. What''s...
# 1   #Person1#: Have you given the puppies food yet...
# 2   #Person1#: How can we get in touch with you?\r...
# 3   #Person1#: Could you tell me what university y...
# 4   #Person1#: Hey Rocky! You''ve been sitting aro...
# ..                                                ...
# 70  #Person1#: Do you think our headmaster is goin...
# 71  #Person1#: Here''s your hot dog and beer. What...
# 72  #Person1#: How may I help you?\r\n#Person2#: I...
# 73  #Person1#: Jack, I think it''s best that I act...
# 74  #Person1#: We''d like to have a look around yo...
#
# [75 rows x 10 columns]
