# %%
import pandas as pd

# %%
scored_path = '/home/ramprasad.sa/factual_evaluation_source_based/datasets/scored/xformer_llm_annotated_scored.csv'
df = pd.read_csv(scored_path)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     docid          model  \
# 0          1374            12          12  test_219        MV-BART
# 1          1375            13          13  test_219           CODS
# 2          1376            14          14  test_219          UniLM
# 3          1377            15          15  test_219           BART
# 4          1378            16          16  test_219  gpt4-32k-0613
#
#                    nonfactual_spans evidence  \
# 0  ['to buy slides and postcards ']       []
# 1                                []       []
# 2                                []       []
# 3                                []       []
# 4                                []       []
#
#                                              summary  factual_error  \
# 0  #Person1# confiscates #Person2#'s camera becau...              1
# 1  #Person1# confiscates #Person2#'s camera and t...              0
# 2  person1 tells person2 it ' s not allowed to ta...              0
# ...
