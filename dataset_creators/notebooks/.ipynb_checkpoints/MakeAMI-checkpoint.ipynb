# %%
import json
import pandas as pd 

def read_data(filename):
    data = []
    with open(filename, 'r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

# %%
import os



from nltk import word_tokenize, sent_tokenize
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
)  # for exponential backoff


from transformers import GPT2Tokenizer
class GPTInference():
    def __init__(self):
        

    @retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
    def get_chatgpt_response(self, prompt):
        # query = f'Article: {doc}\n{instruction}\n{prompt}'
        response = openai.ChatCompletion.create(model="gpt-4-32k-0613",
                                       messages=[
                                           
                        {"role": "user", "content": f'{prompt}'},   
                        ], 
                        )
#         print(query)
#         print(response)
        return response['choices'][0]['message']['content']

# %%
def make_gpt4_summaries(read_file, out_file):
    df = pd.read_csv(read_file)
    print(df.head())
    gpt_model = GPTInference()
    df_dict = {
        'DocID': [],
        'Dialogue': [],
        'Model': [],
        'Summary': [],
        'origin':[]
        
    }
    for dialogue in list(set(df['Dialogue'].values)):
        doc_id = df[df['Dialogue'] == dialogue]['DocID'].values[0]
        instr = 'Generate a concise summary of the conversation given below among multiple speakers'
        prompt = f'{instr}\n{dialogue}\nSummary:'
        summary = gpt_model.get_chatgpt_response(prompt)
        df_dict['DocID'].append(doc_id)
        df_dict['Dialogue'].append(dialogue)
        df_dict['Model'].append('GPT4')
        df_dict['Summary'].append(summary)
        df_dict['origin'].append('AMI')
    df = pd.DataFrame(df_dict)
    df.to_csv(out_file)
    return df

# %%
df_reference = pd.read_csv('/home/sanjana/explainable_factual_evaluation/datasets/fact_annotated/old_model_annotated/dialogue_aggrefact.csv')

df_reference.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0     DocID  \
# 0             0             0           0  13809941
# 1             1             1           1  13809941
# 2             2             2           2  13809941
# 3             3             3           3  13809941
# 4             4             4           4  13809941
#
#                                             Dialogue                 Model  \
# 0  Thelma: i dont have anything to wear\nLouisa: ...             human_ref
# 1  Thelma: i dont have anything to wear\nLouisa: ...            bart_large
# 2  Thelma: i dont have anything to wear\nLouisa: ...         mv-bart_large
# 3  Thelma: i dont have anything to wear\nLouisa: ...     co-ref bart large
# 4  Thelma: i dont have anything to wear\nLouisa: ...  condigsum bart large
#
#                                              Summary  w/ Error  SubjObjE  \
# 0      Louisa will lend Thelma her red velvet dress.         0       NaN
# 1  Thelma doesn't have anything to wear. Louisa w...         0       NaN
# 2  Thelma doesn't have anything to wear. Louisa w...         0       NaN
# 3  Thelma doesn't have anything to wear. Louisa w...         0       NaN
# 4     Louisa will bring Thelma her red velvet dress.         0       NaN
#
#   SubjObjE_text  ...  CorefE_text CircE  CircE_text  PredE  PredE_text OutE  \
# 0           NaN  ...          NaN   NaN         NaN    NaN         NaN  NaN
# 1           NaN  ...          NaN   NaN         NaN    NaN         NaN  NaN
# 2           NaN  ...          NaN   NaN         NaN    NaN         NaN  NaN
# 3           NaN  ...          NaN   NaN         NaN    NaN         NaN  NaN
# 4           NaN  ...          NaN   NaN         NaN    NaN         NaN  NaN
#
#    OutE_text SummaC-Conv  SummaC-ZS QuestEval
# 0        NaN    0.224066   0.608673  0.642865
# 1        NaN    0.335007   0.271927  0.513751
# 2        NaN    0.335007   0.271927  0.513751
# 3        NaN    0.329921   0.090210  0.403632
# 4        NaN    0.224066   0.374329  0.651179
#
# [5 rows x 27 columns]

# %%
list(df_reference.keys())[3:]
# Out:
# ['DocID',
#  'Dialogue',
#  'Model',
#  'Summary',
#  'w/ Error',
#  'SubjObjE',
#  'SubjObjE_text',
#  'LinkE',
#  'LinkE_text',
#  'OtherE',
#  'OtherE_text',
#  'GramE',
#  'GramE_text',
#  'CorefE',
#  'CorefE_text',
#  'CircE',
#  'CircE_text',
#  'PredE',
#  'PredE_text',
#  'OutE',
#  'OutE_text',
#  'SummaC-Conv',
#  'SummaC-ZS',
#  'QuestEval']

# %%
filename = "/home/sanjana/modular-summarization/dataset_ami/full_summarization"
write_path = "/home/sanjana/explainable_factual_evaluation/datasets/long_dialogue/raw_dataset/"

train_data = read_data(f'{filename}/train.jsonl')
dev_data = read_data(f'{filename}/val.jsonl')
test_data = read_data(f'{filename}/test.jsonl')

# %%
def make_data(dataset, ):
    df_dict = {'DocID': [],
               'Dialogue': [],
               'Model': [],
               'Summary': [],
              }
    for dat in dataset:
        doc_id = dat['case_id']
        summary = '\n'.join(dat['summary_lines'])
        dialogue = "\n".join(dat['article_lines'])
        model = "human_ref"
        
        df_dict['DocID'] += [doc_id]
        df_dict['Dialogue'] += [dialogue]
        df_dict['Model'] += [model]
        df_dict['Summary'] += [summary]

    df = pd.DataFrame(df_dict)
    return df

# %%
df_train = make_data(train_data)
df_train.to_csv(f'{write_path}/train.csv')

df_dev = make_data(dev_data)
df_dev.to_csv(f'{write_path}/dev.csv')

df_test = make_data(test_data)
df_test.to_csv(f'{write_path}/test.csv')

# %%
model_path = '/home/sanjana/explainable_factual_evaluation/datasets/long_dialogue/model_generated'
df_train_model = make_gpt4_summaries(f'{write_path}/test.csv', f'{model_path}/test.csv')
# Out:
#    Unnamed: 0    DocID                                           Dialogue  \
# 0           0  ES2014d  PM So is\nPM Why not save that .\nME No , you'...
# 1           1  TS3007b  PM Hello .\nME Hey guys .\nID Hi .\nUI Hi .\nP...
# 2           2  IS1009c  PM Okay .\nPM Hello everyone .\nID Hi .\nME Hi...
# 3           3  ES2004a  UI Hmm hmm hmm .\nPM Are we\nPM we're not allo...
# 4           4  TS3003c  PM Okay . Uh\nPM good afternoon .\nME Good aft...
#
#        Model                                            Summary
# 0  human_ref  @@abstract@@\nThe first prototype for the remo...
# 1  human_ref  @@abstract@@\nWhen this functional design meet...
# 2  human_ref  @@abstract@@\nThe project manager opens the me...
# 3  human_ref  @@abstract@@\nThe Project Manager gave an intr...
# 4  human_ref  @@abstract@@\nThe project manager opened the m...
# KeyboardInterrupt

# %%
df_train_model
# Out:
#       DocID                                           Dialogue Model  \
# 0   IS1009a  PM Okay .\nME Okay .\nPM Everybody ready ?\nID...  GPT4
# 1   ES2014c  PM Okay .\nPM Right .\nPM Conceptual design me...  GPT4
# 2   TS3003b  PM Okay .\nPM Everybody found his place again ...  GPT4
# 3   TS3003c  PM Okay . Uh\nPM good afternoon .\nME Good aft...  GPT4
# 4   TS3007b  PM Hello .\nME Hey guys .\nID Hi .\nUI Hi .\nP...  GPT4
# 5   ES2014d  PM So is\nPM Why not save that .\nME No , you'...  GPT4
# 6   ES2004c  PM I'll wait until you're all um hooked up .\n...  GPT4
# 7   TS3003a  PM So uh\nPM good morning .\nUI Morning .\nME ...  GPT4
# 8   IS1009b  PM Okay , is everybody ready ?\nID Yeah ?\nME ...  GPT4
# 9   ES2014a  PM Right , so\nPM start of the first meeting ....  GPT4
# 10  IS1009d  PM Well hi everyone again .\nUI Hello .\nID He...  GPT4
# 11  TS3007d  PM Wouldn't wanna be Project Manager .\nPM Uh ...  GPT4
# 12  IS1009c  PM Okay .\nPM Hello everyone .\nID Hi .\nME Hi...  GPT4
# 13  TS3003d  PM So\nPM Hello .\nME Good afternoon .\nME Sor...  GPT4
# 14  ES2004b  PM Help .\nPM It's up there ? That screen's bl...  GPT4
# 15  ES2004d  PM If you leave them on the whole time you get...  GPT4
# 16  TS3007a  UI Hi .\nID Hi .\nPM Hello .\nUI Oh .\nPM Good...  GPT4
# 17  TS3007c  PM Hello again .\nID Hi .\nUI Hello .\nME Hey ...  GPT4
# 18  ES2004a  UI Hmm hmm hmm .\nPM Are we\nPM we're not allo...  GPT4
# 19  ES2014b  PM Right uh .\nPM So um .\nPM So where's the P...  GPT4
#
#                                               Summary origin
# 0   The speakers, including a project manager (PM)...    AMI
# 1   The speakers are having a discussion about a r...    AMI
# 2   During their conversation, the group discussed...    AMI
# 3   In the third meeting of a group discussing a c...    AMI
# 4   The discussion begins with an overview of the ...    AMI
# 5   In this meeting, the team is discussing criter...    AMI
# 6   During the meeting, the group discusses potent...    AMI
# 7   The project manager "Bart" leads a meeting inv...    AMI
# 8   The conversation started with the Project Mana...    AMI
# 9   In their first meeting, project leader Alastai...    AMI
# 10  The conversation discusses the design and feat...    AMI
# 11  The conversation involves a team of members di...    AMI
# 12  In a meeting with multiple participants, the t...    AMI
# 13  At the meeting, the participants express regre...    AMI
# 14  During a meeting held by a product development...    AMI
# 15  This conversation appears to occur among a tea...    AMI
# 16  Project Manager Danny Wolfs starts the meeting...    AMI
# 17  The project manager (PM) called a meeting amon...    AMI
# 18  The speakers discuss the planning and developm...    AMI
# 19  During a project team meeting, PM orchestrates...    AMI

# %%
train_data
# Out:
# [{'case_id': 'TS3010c',
#   'article_lines': ['PM Okay .',
#    "PM Well , let's start .",
#    'PM What are we doing ?',
#    'PM Oops .',
#    'UI Hmm .',
#    'ID Ah , pinball .',
#    'PM Okay . Okay . Not doing .',
#    'ME Mm . Ah . Hey . Ah .',
#    'PM Uh',
#    'UI Oh .',
#    'ME Now I have my screen back too .',
#    'PM Very good .',
#    'PM Okay .',
#    'ME Yeah .',
#    'PM we have presentations .',
#    "PM So first , it's your turn .",
#    'UI Mine . Oh , great .',
#    "PM Yeah . Isn't it amazing .",
#    'ID Huh .',
#    'ME Yeah .',
#    'ME Very interesting .',
#    'UI Uh',
#    'PM Industrial Designer .',
#    'PM Interface concept .',
#    'UI Yes , well uh',
#    "UI let's uh talk about the interface uh concept .",
#    "UI Uh , first I'll uh I'll uh discuss the buttons we just chose ,",
#    'UI uh show you some samples , uh',
#    'UI uh discuss some colours and design maybe , already .',
#    'UI And uh my personal preferences .',
#    'UI Well we chose the power button to switch the television on and off .',
#    'UI The bu uh',
#    'UI the mute button to switch the volume on and o on and off .',
#    'UI The channels buttons , one to nine ,',
#    'UI and uh off uh uh',
#    'UI zero to nine ,',
#    'UI and the uh button to choose uh higher channels than nine .',
#    'UI Uh the volume and channel quadrants ,',
#    'UI uh left and right , up and down arrows , to uh do the volume and channel .',
#    'UI And the menu menu button to man manipulate the L_C_D_ uh display .',
#    'UI Um , I found some uh interesting uh uh samples . Examples .',
#    "UI Um , well uh what's pretty standard is uh that it's that they're all pretty uh uh high uh",
#    'ME Large .',
#    'UI Yeah . Yeah .',
#    'ME A lot a lot of buttons buttons .',
#    'UI Large and and and pretty thin and uh and long .',
#    'UI Um , power buttons are mostly at the top',
#    'UI uh left or right .',
#    'UI Um , well we see the the the same uh arrows .',
#    'UI Like there .',
#    'UI And uh',
#    'UI Yeah , well arrow b buttons can be blue .',
#    "UI And what's interesting is the the the icons on the buttons .",
#    'UI Some buttons have icons like the play and stop ,',
#    "UI but we don't use that .",
#    'UI But uh , these we we have to choose the right icons , or or letters .',
#    "UI Uh this is the V_ for volume , but they're both uh a V_ .",
#    "UI So it's it's not really very uh clear what's the function of that .",
#    'ME Yeah .',
#    'UI Um',
#    "UI Yeah . So , that's",
#    'PM Can you go back one page ?',
#    'PM For the uh menu , what do we use for that ?',
#    'UI Uh , well',
#    "PM We don't have buttons for the menu .",
#    'PM Or we may have to use channel of the volume and channel .',
#    'UI Yeah .',
#    'UI I thought that was our uh idea .',
#    'PM Okay .',
#    'UI So , uh how',
#    'PM But uh',
#    'PM You have to put it on the',
#    'UI Like this .',
#    'PM Yeah .',
#    'UI Or or this .',
#    'UI And that the menu button is okay .',
#    'PM Yeah but , has to be clear that you can use the arrows .',
#    'UI Yeah , okay .',
#    'ME Yes .',
#    'UI Uh , so the',
#    'UI The icons on the arrows , as well , you mean .',
#    'PM Mm-hmm . Yes . The second one .',
#    'UI Yeah .',
#    "UI Uh , well that's something to uh think about .",
#    'PM Okay .',
#    "ID Uh , maybe I'll have something in my uh presentation .",
#    'ID And you will see it .',
#    'UI Okay .',
#    'ME Okay .',
#    "UI Um , well I don't I don't know if we have to discuss this already , or in the next uh meeting .",
#    'UI But uh , as we have to uh to to design the the case and the whole uh remote control in our uh our our corporate uh company uh uh colours and the logo , I would uh recommend a yellow case .',
#    'UI Uh , round edges .',
#    'UI The logo at the bottom .',
#    'UI And uh , well maybe each each uh set of buttons uh has uh has his own colour .',
#    "UI So , it's good .",
#    'UI Uh , recognisable .',
#    'UI K so , I think .',
#    'PM Not too much colours .',
#    'UI Uh , no . Not too much .',
#    'UI But uh',
#    "PM No , it's not flower power .",
#    'UI No , no , no .',
#    'UI But this has to be has to be trendy',
#    'UI and uh and',
#    'PM S okay .',
#    'UI Uh , yeah so good uh good icons on the buttons , and uh and big buttons is my uh personal uh opinion .',
#    'PM Okay .',
#    'UI That was that .',
#    'PM Thank you .',
#    "PM So , you're next .",
#    "ID I'm next , okay .",
#    'ID Yes . No .',
#    'ID Here we go .',
#    'ID Uh , at first we will uh I will f uh say something about what younger people want ,',
#    'ME Okay .',
#    'ME Mm-hmm .',
#    'ID our uh group w uh w uh we want to uh sell our remote controls to .',
#    "ID And then , I'll discuss what my opinion is about the costs , about uh what battery is in it , what kind of buttons also .",
#    'ID First uh , the younger people , they want like soft mat uh materials and primary colours .',
#    'ID Like , totally yellow , totally red .',
#    "ID Uh , so it's visible .",
#    'ID Uh , the shapes are curved and round ,',
#    'ID like uh you also said .',
#    "ID Maybe it's nice to uh get a remote control not like all the other ones , straight and uh flat and long .",
#    "ID But to give him the shape of your hand , so you it's easier to use or something like that .",
#    "ID But that's just an idea .",
#    "ID And then , I'll have to discuss about the costs uh of all the things for the remote control .",
#    'ID The battery , there are few options .',
#    'ID Uh , I think the best option is to use uh the basic battery .',
#    'ID So , everybody can buy it uh at the at the supermarket .',
#    'ID Or use uh a k uh kinetic battery like uh within a watch .',
#    "ID When you uh shake it a few times , it it's loaded .",
#    "ID Uh , the the form of the remote control , I think it's also nice have it curved .",
#    "ID And maybe like it's hand-shaped .",
#    'ID Uh , so uh you take it here in your hand and here are the buttons .',
#    'ID Uh material , you use plastic . Hard plastic',
#    "ID uh because uh it won't have to burst uh like in the in one time .",
#    'ID And also rubber',
#    'ID because the younger people like that ,',
#    'ID what we see in the research .',
#    'ID Uh the push-buttons .',
#    'ID We have one new thing uh discovered .',
#    "ID It's a scroll push uh thing like a mouse .",
#    "ID Maybe it's uh easy to use uh for the channels .",
#    'ID When you want to go m move up , you just scroll up',
#    'ID and click on the button , if you wanna see the next , uh if you wanna see that channel .',
#    "ID And also for the mouse , uh for the volume , it's also uh easy to use .",
#    'ID Just scroll a bit up , scroll a bit down .',
#    "ID And that's also easy just w when you have a thing like this , and you get it here .",
#    'ID You can do it with your thumb .',
#    'ID And with your l left hand you can uh push the buttons',
#    'ME Hmm .',
#    'ID uh if you push uh channel one , you can see channel one .',
#    'ID The electrics um with a scroll push uh button , we must use regular uh chips .',
#    'ID There are also uh simple chips .',
#    'ID They are uh cheaper .',
#    'ID Um , but then we have just a basic uh uh remote control ,',
#    "ID and I think there are a lot of those uh things , and people won't buy it any more .",
#    'ID They have seen enough of it .',
#    'ID And you have also advanced um chips .',
#    "ID But that's with the L_C_D_ uh screen .",
#    'ID And the costs will increase a lot more .',
#    'ID And I think our budget is too low to use and an L_C_D_ ,',
#    'ID and the chip who is more expensive .',
#    "ID And maybe it's also then uh thoughtful if we u uh use uh as um different kind of uh shapes for the for remote control ,",
#    'ID that we then use the primary colours .',
#    'ID Like , you get a yellow uh remote control , red one , blue one , et cetera .',
#    'ID You have any more questions about this ?',
#    'ID I think the main thing is we look at the costs .',
#    'ME Yep .',
#    'PM Hmm .',
#    'ID And not too basic ,',
#    'ID not a basic remote control , who everybody already has .',
#    'ME Yeah .',
#    'ME But , thi i uh',
#    'ME This is with an L_C_D_ ? No ,',
#    'ID Not with an L_C_D_ .',
#    'ME not .',
#    "PM No , isn't .",
#    'ID No .',
#    'PM But the L_C_D_ is easy when you use the scroll uh buttons .',
#    'PM Then you can scroll , you see what number , and then you push .',
#    'ID Yeah .',
#    'ID But then , what I say , the costs will uh get a lot higher .',
#    "PM But then it's not easy to use scroll uh wheel .",
#    "ID Th then you'll see it on the television .",
#    "PM If you don't",
#    'PM Hmm , yes . But then . Yeah , then you go one down one up .',
#    'ID Yeah',
#    'PM When you scroll .',
#    "ID but l when you see a menu uh on the television , it's like you see uh one to twenty , you go uh uh s scroll up , and push number tw twenty .",
#    'PM Yeah',
#    'PM but like we said before , it has to be used on every television .',
#    'PM So you may not be uh',
#    'PM No .',
#    'PM The television must do that .',
#    'ID Mm-hmm .',
#    'PM So',
#    'ID Yeah , I think the younger people will have newer televisions , which can provide our uh remote control .',
#    'PM Yeah',
#    'PM but young people have to have all their uh room .',
#    'PM And mostly they are smaller .',
#    'ID Yes .',
#    'PM So',
#    "ID But that won't be a problem . I think .",
#    'PM Most the times that are not advanced televisions .',
#    'ID No ,',
#    "ID but then we'll get to the regular uh remote controls .",
#    'ID And I think , what I said , everybody has them uh has them already .',
#    'ID And they go to a uh supermarket and buy them uh for two Euros .',
#    'ID Uh , and ge and get the most cheapest uh thing .',
#    'ID And I think we must look further to uh to devel d develop something news .',
#    'PM Okay .',
#    'ME Uh , can you give an indication in b uh in the cost difference between uh the chip with L_C_D_ or without ?',
#    'ID I got it on my screen and it was uh higher .',
#    "ID But I don't know uh how much higher .",
#    "ME 'Cause it",
#    'ME I think if we have an L_C_D_ , it will also sell a lot better .',
#    "PM That's important .",
#    "ID That's true .",
#    'ME And that might uh bring back the costs uh',
#    "ID But then we'll",
#    'ID I think we must discuss who uh what will be better . If we have a better shape of the um remote control , or better options on it .',
#    'ID With a scroll menu , a w scroll thing , and a L_C_D_ . And then a flat um remote control .',
#    'ID Or , a more hand-shaped remote control , with scroll , without L_C_D_ .',
#    'PM Yeah .',
#    'PM Maybe you can look how how much it is for the L_C_D_ .',
#    'ID I can uh look on my uh',
#    "PM It's very important .",
#    'ID Uh',
#    'ID Note that the push-button requires a simple chip chip .',
#    'ID A scroll wheel requires minimally a regular chip , which is a higher price range .',
#    'ID The display requires a advanced chip , which is which in turn is more expensive than the regular chip .',
#    'PM Yeah , more expensive .',
#    'PM But how much ?',
#    "ID Doesn't say .",
#    'PM Oh .',
#    'ME Huh .',
#    'UI Hmm .',
#    'PM Okay .',
#    "ID That's from my manufacturing division .",
#    'PM Okay .',
#    "ME 'Kay .",
#    'PM Well , thank you .',
#    'ME My turn ?',
#    'ID Yes ?',
#    'PM Next .',
#    'ME Mm . So',
#    'ME So',
#    'ME Yeah .',
#    'ME So , my uh presentation is about trend-watching .',
#    'ME Uh , I did some trend-watching .',
#    "ME It's very important to uh keep up with latest trends . 'Cause if you don't , you won't sell .",
#    'ME So , well how we did do that ?',
#    'ME Uh , well we made an investigation of the market , by Trendwatchers .',
#    'ME They uh watch in uh cities like uh Paris and Milan .',
#    'ME Of course , well known for their uh trend uh trends .',
#    'ME And well , uh what did you find ?',
#    'ME Uh , we have two groups , young and trendy , and the old and rich .',
#    'ME Well th and the young and trendy , they uh they starting to like uh fruit and vegetables uh as a theme for n uh clothes , shoes , and also uh products .',
#    'ME And um , material ? That should feel have uh a spongy feeling .',
#    'ME And to get a feeling for what it is , uh here is an image of it .',
#    'ME Then the old and rich .',
#    'ME They like uh dark colours , and simple , recognisable shapes .',
#    'ME And um , they also like uh familiar material , uh especially wood .',
#    'ME Now , another picture .',
#    'ME To get a feeling for this .',
#    'ME Well , uh then already come to my personal preferences .',
#    'ME We uh aim at the younger market .',
#    'ME So , we should also be uh look at their uh trends .',
#    "ME However , with trends it's always if there's it's now .",
#    'ME It it it might last one year , and next year it be uh can be totally different .',
#    'ME And I think we want to sell our product for longer than one year .',
#    'ME So , we m must not just only look at what the trend is now ,',
#    'ME as it might be totally different next year .',
#    "ME So , that's uh one thing to keep in mind .",
#    'ID Changing covers .',
#    'ME Yeah .',
#    'ME Any questions ?',
#    'ID Nope .',
#    'UI No .',
#    "PM No . It's clear .",
#    "PM So now , it's uh",
#    "PM Ah , let's see .",
#    'PM Now , w we have to decide',
#    'PM Well , we have to decide on the concept .',
#    "PM So , we have to look at 'S next . Components and user interface concept .",
#    'PM So',
#    'PM Now , we have to make some concept .',
#    'PM Maybe one of you can paint it on the board .',
#    'PM First , uh user interface .',
#    'ID Uh , uh-uh .',
#    'ID How w how we how we make it ? Uh',
#    'PM Yes , a concept on uh',
#    "ID Shouldn't we first discuss about like what w we all",
#    'PM Just',
#    'ME Yeah .',
#    'PM Yeah ,',
#    'PM but maybe we can paint it . Uh , what do we want ?',
#    'ID Yeah , but if I paint with',
#    "PM I'll paint . Okay .",
#    'PM Well',
#    'ME Mm .',
#    'PM Something like this ? Or',
#    'UI Mm , yes .',
#    'PM Shapes or What do we need ?',
#    'ME Can make several uh concepts .',
#    'UI What ?',
#    'PM Yes , okay .',
#    'ME We have this , and we had the idea of an um a more uh uh uh like sh in the shape of your hand .',
#    'PM Okay .',
#    'ID More like something',
#    'ME Yeah I I I uh yes .',
#    'ID M like',
#    "ID Yeah I can't dr I can't draw it .",
#    'ID Uh',
#    'PM And you have to .',
#    'ID I have to .',
#    'PM Yeah .',
#    "ID I'm not a designer .",
#    "ID It's more three D_ .",
#    'ID Like , um when you have',
#    'ID a part here .',
#    'ID This is the remote control .',
#    'ID And then you have something like th this under it .',
#    "ID So , it's easier to get it like this .",
#    'UI Mm .',
#    'UI Yeah .',
#    'ME Yeah .',
#    "ID It's like a gun .",
#    'ME A g',
#    'PM So , it has to be soft ?',
#    'ME Mm . .',
#    'ID And it has to be soft , yeah .',
#    'PM Okay .',
#    'ID So , you can squeeze in it and',
#    'PM And uh , the buttons ?',
#    'ID Sorry ?',
#    'PM Buttons .',
#    'ID Buttons on top of it .',
#    'ID And here .',
#    'ID The scrolling . You can do it with your thumb .',
#    "PM No , it won't .",
#    "UI But but i that's the only scroll uh button on it then ?",
#    'ID But now we use one scroll button and the other one is here .',
#    'ID One till uh uh zero till nine .',
#    'PM But , well there one for the sound and one for the channels .',
#    'UI Yeah , okay .',
#    'UI But but how',
#    'ME Yeah .',
#    'ID And the b',
#    'UI Yeah .',
#    'ID Yeah ?',
#    'UI How',
#    'ID Or two buttons .',
#    'UI Okay .',
#    'ME And i if we go to uh',
#    'PM Uh , two scroll uh wheels .',
#    'ID If uh',
#    "ID 'Kay c If we do",
#    "ID If we use one , then we'll have just a switch on it ,",
#    "ID and you'll just switch it ,",
#    "ID and now it's the sound to switch back",
#    'UI Mm .',
#    "PM That's th that's more difficult .",
#    'ME But if we have uh a me Yeah .',
#    "PM It's better in",
#    'ME If we have a menu , uh how do we uh choose other options ?',
#    'ID with the menu uh button .',
#    'ID And then you also can scroll uh scroll in it .',
#    'ID Just not like all the other ones , with uh this thing , and uh here an arrow , here an arrow , here an arrow , here an arrow .',
#    'ME Yeah .',
#    'ID Because uh , from h hundred uh remote controls , ninety nine have it .',
#    "PM But if we don't have a L_C_D_ we don't have a menu .",
#    'UI Yeah .',
#    'ID Uh , then we have it on the T_V_ , the menu .',
#    'ME Uh-uh .',
#    'PM Yeah , but again maybe th How do we know the T_V_ can handle it ?',
#    "PM You don't know .",
#    "PM So , there's no menu .",
#    "ID I don't know .",
#    "ID It's like some sort of uh teletext option , but we don't have teletext .",
#    'PM No .',
#    "PM So you can't use it .",
#    'ID And if we put an L_C_D_ thing on it , then the costs will uh be much higher .',
#    'PM Okay ,',
#    'PM we make two concepts .',
#    'PM One with L_C_D_ . One without L_C_D_ .',
#    "ID 'Kay .",
#    'ID But you all like this kind of thing .',
#    'ID Uh',
#    'PM Good concept .',
#    'PM But',
#    'ID With the scroll button .',
#    "PM That's one .",
#    'ID And and this one has to be soft .',
#    'ME Uh-uh .',
#    'ID And this has to be harder ,',
#    'ID because when it falls , it mu mu must not burst .',
#    'ID Or some kind of rubber around it .',
#    'UI Mm-hmm .',
#    "PM It's one .",
#    'PM Two . Number two .',
#    'UI And you can and you can uh make the the power button as a trigger .',
#    'ID Yeah . Yeah .',
#    'UI Like uh',
#    "ID Ah that's nice .",
#    'ID Here . Trigger .',
#    'PM No .',
#    'UI Just to uh',
#    'PM But when you handle it , you put it on and off .',
#    "PM It's not good to use .",
#    "PM Yeah , but I'll zap .",
#    'UI Oh , like a',
#    'UI Yeah .',
#    'PM Fuck . Out .',
#    "PM No , it's not good .",
#    'ME Yeah .',
#    'PM Now , second concept .',
#    'PM One with L_C_D_ , one without L_C_D_ .',
#    'PM Then uh',
#    'PM Paint it .',
#    'ID Paint it ?',
#    'ID With the scroll thing on , like this ?',
#    'PM One with two scroll buttons and one with without .',
#    'PM Yeah .',
#    'PM Uh , one with a with a menu , and one without a menu .',
#    'ID So ?',
#    'PM And the one with with a menu has an L_C_D_ .',
#    'ID Draw it .',
#    'PM Unbelievable .',
#    'PM Do I have to do everything .',
#    'PM Blank .',
#    'PM You have',
#    'PM Not so difficult .',
#    'ME Yeah .',
#    'UI But if you put push the the menu button',
#    "PM Uh , that's the menu .",
#    'UI Yeah , wh what',
#    'PM There for the L_C_D_ screen .',
#    "UI Yes , but you don't know which of the scroll buttons you have to choose .",
#    'PM You have to',
#    'PM For the menu .',
#    'UI Yeah .',
#    'PM Mm-hmm .',
#    'PM One that way .',
#    'PM And one that way .',
#    'PM So',
#    'PM Then it depends on the cost .',
#    'PM S On and off .',
#    'ID But is it easy to use ?',
#    'ID When you have it on your left side ,',
#    'ID and',
#    "PM When it's not too big .",
#    'PM Just like a a phone .',
#    'UI Mm-hmm .',
#    "ME M uh yeah , maybe it's better if the uh scroll-wheels are um",
#    'ID Separate , more separate , h yeah .',
#    'ME more separate , yeah .',
#    'PM Yes , okay .',
#    'ME Like , you have the menu button in between uh',
#    'ID Yeah .',
#    'ID On the left a scroll button , and on the right a scroll button .',
#    'ID But would it be easy to use then ?',
#    "ID If it's like you have a big uh",
#    'PM Very good .',
#    'PM Is it better ?',
#    'PM When you uh the menu , you have to go there there there there .',
#    'ID I also think this concept is not what the young people were looking for .',
#    'ME Yeah .',
#    'ID They were like round curves ,',
#    'ID uh different uh',
#    "PM Yeah , okay . That's that's the outside .",
#    'ID Okay , okay , okay .',
#    'PM But now the',
#    'PM First the buttons .',
#    'ID Mm-hmm .',
#    'ME Think we have we have now two buttons missing .',
#    'ME The uh um',
#    'ME The mute button .',
#    'PM Sorry ?',
#    'ME We have two buttons missing .',
#    'ME The mute button .',
#    'ME And um , the to to uh have to uh numbers',
#    'PM Mute . And the other .',
#    'ME Okay .',
#    'PM Yeah . Not so difficult .',
#    'ME But , uh',
#    "ID Personally , I think two scroll buttons uh aren't easy to handle .",
#    'PM But how do you wanna solve it ?',
#    'ID With the switch button .',
#    "PM Yeah but on the menu that's not uh easy .",
#    'ID No',
#    'PM Then you go down , you switch , you go into the right , you switch , you go down .',
#    'ID like uh',
#    'ID Oh , you mean like that .',
#    'PM Yeah .',
#    'ID Uh , then you can also have like uh th um',
#    'PM A joystick .',
#    'ID Yeah , and joystick , I think .',
#    'PM Yeah .',
#    'PM But is it uh',
#    'PM Does that break , a joystick ?',
#    'PM Or a small one just like in a laptop .',
#    'ID Yeah like in a laptop , s uh s some sort of thing .',
#    'ID A little bit bigger ,',
#    'ID with easier thi',
#    "PM Mean , it's better .",
#    'PM But how expensive it is ?',
#    "ID I don't know .",
#    'PM Oh . Why do I pay you for ?',
#    'PM Um , well um',
#    'PM Better ideas .',
#    'ME Okay .',
#    'ID Or no scroll uh things .',
#    'ID Just a shape .',
#    'ID And',
#    "ID No , no . It won't work .",
#    "PM For the young peoples I think scroll button's good .",
#    'ID Yeah . Uh-huh .',
#    'PM So',
#    'PM Think we have to keep them .',
#    'ID Or a remote control more like joystick .',
#    'PM Yeah , but is it',
#    "PM That's not expensive than uh Joystick is better .",
#    'PM A small one .',
#    'ID A small one like this , like a Nintendo uh k',
#    'PM No',
#    'PM just like in a',
#    'ID Playstation thing .',
#    'PM a laptop .',
#    'PM Small , round .',
#    "PM Then it's not so big .",
#    'ID No , no , no .',
#    'ID I mean the the shape of the remote control .',
#    'PM Oh the sh',
#    'ID Just like a Playstation thing .',
#    'PM Yeah ,',
#    'PM but then you can',
#    'ID Yeah .',
#    'PM So',
#    "PM Maybe , if it's possible , it's not too expensive , I think a joystick is better .",
#    'PM A small one .',
#    'PM So , please look at it .',
#    "ID No , that's okay ,",
#    'ID I got',
#    'ME And on the L_C_D_ , how much it costs ?',
#    'ME Uh , it costs extra ?',
#    'ID Uh',
#    "ID they're not uh in details .",
#    "ID It's more expensive or less expensive , huh ?",
#    'PM Yeah we I think you get it .',
#    'PM So , after this meeting you have half an hour to uh fix it .',
#    'ID Then I have to come with it .',
#    'PM Yes .',
#    'ID I got my personal costs .',
#    "ID I I don't I don't know the costs .",
#    'PM Your problem . Not mine .',
#    "ID Then I'll uh make something up .",
#    'PM Okay .',
#    'PM So , do we have other concepts ?',
#    'PM Then for the components , we use a normal battery .',
#    'UI Mm , yeah .',
#    "PM Then it's Ch cheapest way , I think .",
#    'ID Yeah , or the or the kinetic uh with normal battery .',
#    'PM No , no kinetic .',
#    "ID Yeah , I think it's uh , yeah ,",
#    'PM Kinetic is uh ch makes it more expensive .',
#    'ID more expensive . Yeah .',
#    'PM So we use a normal battery .',
#    'ME Yeah .',
#    'UI Yeah .',
#    'ID Okay .',
#    'ME Yes .',
#    'PM Chip . Depends on the L_C_D_ .',
#    'ID Depends on the scroll .',
#    'PM Scroll .',
#    'ID If we use a scroll , then we have the uh regular chip .',
#    "ID If we don't use a scroll , then we can use the simple chip .",
#    "ID And that's",
#    'PM Yeah .',
#    'PM And uh , we If you use the L_C_D_ , we have to',
#    'ID Uh the most expensive .',
#    'PM Yes , okay .',
#    'ID Yeah .',
#    'PM So , depends on the L_C_D_ and the scroll .',
#    'ID If we',
#    'ID Yeah .',
#    'PM Okay .',
#    'ID If we',
#    'ID No okay scroll-wheel .',
#    'ID So , I have this .',
#    'ID So , it will be uh the advanced chip , or the uh regu uh or the regular chip .',
#    'PM Okay .',
#    'PM So , uh the shapes of the design depends on the L_C_D_',
#    'PM and',
#    'PM But , it has to be small .',
#    'PM I think .',
#    'ID Or shall we just put it on the pistol thing ?',
#    'ID And then just put also on L_C_D_ on it ?',
#    "PM If you have pistol , it L_C_D_'s not easy .",
#    'PM Y y Yeah but',
#    'ID Just use your thumb .',
#    'PM If you use a phone .',
#    'ID If you',
#    'ID Yeah . I use my thumb .',
#    'PM k Yeah , but but then you have it .',
#    'PM Like , th if you have pistol , you have it so .',
#    'ID Yeah .',
#    'PM And the screen is',
#    'PM Well , then you have to keep it this way to look at the screen .',
#    'ID If you have a joystick on',
#    'ID No ,',
#    'ID if you have like uh an uh uh a ni a uh Playstation uh game controller .',
#    'PM Yeah .',
#    'ID And you move up , f forward , down , left .',
#    'ID Then you have uh just , yeah , a little bit curved .',
#    "ID It's not just uh straight .",
#    'PM No . No , no .',
#    "ID That's how we use it .",
#    'ME Uh',
#    "ID That's why they make joysticks like that , I think .",
#    'PM Yeah , but then you look forward .',
#    'ME Uh , yeah , but',
#    'PM And then you can y',
#    'ME Yeah .',
#    'ID Yeah ?',
#    'PM N well , if you have to look at it .',
#    'ME If you',
#    "ID 'Kay . Here's our designer .",
#    'ME If we have uh then something standing here , with the L_C_D_ .',
#    'ID Yeah .',
#    'PM Then it goes like this .',
#    'ID Yeah , why not .',
#    'PM If th n well',
#    "ID It's for the younger people .",
#    'PM Yes , of course .',
#    "ID It's something new .",
#    "UI It's uh",
#    "PM That's good good .",
#    'PM But the um ,',
#    'PM it may not break .',
#    'ID Now we put uh rubber around it .',
#    "PM Okay . If that's possible .",
#    'ME Um , Yeah .',
#    'ID Hard plastic , uh the shape , and around it hard uh around it rubber .',
#    'ID And the uh the hand shape is also rubber .',
#    'PM Okay .',
#    "ME I can't see the .",
#    'UI Or you can uh turn it inside .',
#    'ME But , uh the easy of',
#    "UI But that's",
#    "ME uh , th the ease of use wasn't uh the most important uh aspect of it .",
#    'ID Huh .',
#    "UI No , that's true .",
#    "ME Uh , for us it's about to sell it .",
#    'ME Uh',
#    'PM Yeah of course .',
#    'ID This is something new .',
#    'PM Okay .',
#    'PM Then this is the design .',
#    'PM And the buttons are on the next page .',
#    'PM So , depends on the cost .',
#    'PM So ,',
#    'ID Costs are okay .',
#    'PM um we have one minute .',
#    'UI .',
#    'ME One .',
#    'PM I think .',
#    'ME No .',
#    'PM No .',
#    'ME You have more .',
#    'PM More . Seven .',
#    'ME You have still ten .',
#    'PM Next meeting . Thirty minutes .',
#    'PM So hurry up .',
#    "ID Oh , that's us together .",
#    'PM You two stay here .',
#    'PM Paint it .',
#    'UI Okay .',
#    'PM Now you have to .',
#    'PM So',
#    "PM I think it's clear .",
#    'PM Check your mail .',
#    'PM So',
#    'ME Yeah .',
#    'ID Yes .',
#    'PM It has to be ready in the next meeting .',
#    'PM So',
#    'ME What ?',
#    'UI Cookie .',
#    'ME Okay .',
#    'PM Next meeting is called the detailed design .',
#    'PM So',
#    'PM Everyth everything has to be ready .',
#    'ME Okay .',
#    'PM Thanks for your attention .',
#    "ID 'Kay .",
#    'ME See you at the next meeting .',
#    'ID Bye bye .'],
#   'summary_lines': ['@@abstract@@',
#    'The industrial designer gave a presentation on the interface concept, discussing which buttons will be needed and then looking at some examples of existing remote controls.',
#    'He suggested using a yellow case with rounded edges and the logo at the bottom, and large, clearly marked buttons.',
#    'The interface expert informed the group that young people like curved shapes, soft materials and primary colours, and suggested making a hand-shaped remote in plastic and rubber.',
#    'They put off making a final decision about using an LCD screen, scroll buttons and a menu button until they could find out about costs.',
#    'He talked about the possibility of using a scroll button, and the different chips which could be used.',
#    'The group discussed using an LCD screen, but did not have enough information about costs to make a decision.',
#    'The marketing expert talked about new trends, including the trends for spongy materials and fruit and vegetable themed products.',
#    'The group had a discussion and decided to create two designs, one with an LCD screen and one without, and the interface designer drew them on the board.',
#    '@@actions@@',
#    'The interface designer will find out how much an LCD screen will cost.',
#    'The industrial designer and user interface designer will stay in the room to design the prototypes.',
#    '@@decisions@@',
#    'The remote will use a normal battery.',
#    'The case will be made of hard plastic and rubber.',
#    '@@problems@@',
#    'Whether to use an LCD screen or not.',
#    'If they can use a menu on the TV screen if the remote does not have an LCD.',
#    'There was a lack of information about the cost of an LCD screen.',
#    'Whether to have a trigger-shaped power button.',
#    'Whether to use a joystick rather than a scroll button to navigate the menu.']},
#  {'case_id': 'IS1002c',
#   'article_lines': ['PM Afternoon guys .',
#    "PM It's gonna be .",
#    'ME Rock and roll .',
#    'PM Oh .',
#    "PM 'Kay .",
#    'ME So do we need to re-train Mike on how to put his mic on ?',
#    'ID Think s',
#    'PM We may do .',
#    'ME Okay , can he get it all by himself this time ?',
#    "PM I dunno , I'm feeling like a big boy .",
#    'ID Mm . Pro',
#    'ID Probably not ,',
#    "ID 'cause he's 'S been listening to too much .",
#    'ME So',
#    "ID He's getting retarded . Yay .",
#    'ME I believe I can fly .',
#    'UI Alright well we got some exciting stuff for you guys .',
#    'ID Or not .',
#    'UI Or not .',
#    'ID Yeah .',
#    'ME Just what I needed was something exciting .',
#    "ME Remember , I'm an old man .",
#    "PM 'Kay , ready to go ?",
#    'UI All ready .',
#    "PM 'Kay so we've got our conceptual design meeting .",
#    "ID Apparently I'm old as well .",
#    "PM Hopefully we've all got exciting ideas now .",
#    "ME Thirty's really young , eh ?",
#    'UI We do .',
#    'PM Uh k exciting ideas .',
#    "PM 'Kay so here's our agenda our agenda . Um",
#    "PM I'm gonna open .",
#    "PM I'm gonna talk for a bit about what we're gonna do .",
#    "PM I'm gonna take some notes .",
#    "PM We're gonna all do a presentation ,",
#    "PM and then hopefully we're gonna make some decisions now .",
#    'PM Yep .',
#    'UI Alright .',
#    'PM Well when I say hopefully , we have to . So',
#    "PM I'm gonna let you guys talk before we make decisions .",
#    'PM And does anyone really want to go first ?',
#    "UI I guess I'll go first .",
#    'PM You p two ?',
#    'UI Yeah .',
#    "PM What's",
#    'UI Component , I think . Yeah .',
#    'PM Components design .',
#    "UI Yep that's it .",
#    'ID Presented by name .',
#    'UI My name is .',
#    'ME Jose he man is .',
#    'PM Your name is name ?',
#    'UI My name is name .',
#    'PM Huh hi name .',
#    'ID My name is Inigo Montoya .',
#    'ID You killed my father .',
#    'UI Sorry',
#    'ID Prepare to die .',
#    'UI I did this in a bit of a rush .',
#    'ME N name .',
#    "UI So so here's a look inside your really old-looking remote control .",
#    'PM Right .',
#    "UI Um you've got a printed a printed uh circuit board here ,",
#    "UI and you've got all these buttons which kinda press down little rubber nubbies into these little holes that activate",
#    "PM We've all broke a remote control ri um s yeah .",
#    "ME I've",
#    "UI Yeah we've all broken a remote control .",
#    "UI So you've also got um you've got your chip here , your batteries here , and some sorta electronics . Um",
#    'ME I just love you tech guys , huh .',
#    "ID Yeah there's a thingy and a dingy and",
#    'PM You press this and it does th',
#    'ME Yeah y do jabber',
#    'UI Well',
#    "UI so you've got here's here's a transistor , and this amplifies your signal ,",
#    "UI um you've got the L_E_D_ here on the end of the uh uh on the end of the printed circuit board .",
#    "UI Um you've got a couple diodes here for I don't know who and whatnot .",
#    'PM I dunno who and whatnot .',
#    'UI So exactly .',
#    'ID Nah .',
#    "UI So um we've got a i in this in this uh drawing he uh in this example here , this is a eighteen pin um uh chip I dunno .",
#    'ME P',
#    'ME Yeah .',
#    "UI Uh it's two double A_ batteries .",
#    'UI This is pretty standard remote .',
#    'UI So here are options for our power sources .',
#    "UI You can use a basic battery , which we've already discussed ,",
#    'UI um th our tech department also said we have the option of doing some kind of hand dynamo where maybe you crank it or something like that .',
#    "PM 'Kay .",
#    'ID I wanna change that .',
#    "UI I don't know if that's really",
#    'ME I I gotta I gotta flashlight , and uh',
#    "UI I don't know we got some qu crazy guys down there in that department so",
#    'PM Okay .',
#    'UI You shake it .',
#    'ME yeah',
#    "ME but it's interesting 'cause you shake it like this .",
#    'UI Yeah .',
#    'ME Like this .',
#    "UI So that's the next bullet is the um the kinetic provision of energy ,",
#    "ME And that's on the camera .",
#    "UI so it's like that flashlight where you have to shake it .",
#    'ME Yeah .',
#    "PM 'Kay .",
#    "UI Uh we've got solar cells ,",
#    "UI which I don't think is a very good idea because um you could not use your remote at night",
#    "UI which doesn't make a lot of sense .",
#    "PM Mm 'kay .",
#    "UI And finally we've got our cradle o our power cradle idea .",
#    'PM Okay so we basically have battery versus cradle here ?',
#    'UI M battery versus cradle I think is yeah .',
#    'PM Okay .',
#    'ID I like the kinetic .',
#    'PM So we have battery versus cradle',
#    'ME I g I I figured you would . Yes . Yeah .',
#    'UI It could be fun .',
#    "PM It's actually a novel thing",
#    'PM because you could sell it a as a novelty ,',
#    'PM just to be actually serious for a minute here ,',
#    'UI Yeah .',
#    'PM you could',
#    'UI Well it is it is more uh I mean it is more eco-friendly than the than the cradle',
#    "UI 'cause you're still using power off the grid with the cradle . So um",
#    'PM Mm .',
#    'PM Hmm .',
#    'UI our case design .',
#    'UI We have uh choices in materials',
#    'UI and choices in the general shapes that we can do .',
#    'UI Our material choices are a plastic latex um ty or plastic , a rubber latex type thing , uh wood , or titanium .',
#    "UI If we go with titanium we're gonna be uh limited in the amount of shapes we can do",
#    "UI because it's tough to shape the titanium , and uh",
#    'UI Yeah pers',
#    "PM Wood wood would ge would give us a little bit of a marketing niche , wouldn't it .",
#    'UI I think wood i',
#    'ME It it it',
#    'PM Nah .',
#    "UI I I can't see anybody wanting to use a wooden remote ,",
#    "UI it's just anti-technology really , you know .",
#    'ME Uh .',
#    'PM Okay .',
#    'PM Hmm .',
#    "ME Uh uh to me in a marketing sense it's not it's not relative .",
#    'ME We can we can o we can uh accentuate whatever',
#    'ME whatever product you put in there we can find a way to accentuate it .',
#    'UI Right .',
#    'UI And what we may be able to do , and I think this might be the best option is to combine some a couple of these .',
#    'PM Okay .',
#    'UI Um my recommendation personally would be to do some kind of a plastic inner shell with a like a rubber outer shell ,',
#    'UI to make it um to mak uh like a thick plastic inner shell',
#    'UI and a t um kind of a to have that rubber outer shell to make it more durable ,',
#    'UI and also maybe i I think it feels a little better than the plastic .',
#    "PM 'Kay . Do you get a good grip on the rubber ?",
#    'UI Yeah um',
#    'PM Yeah okay .',
#    'ME And if you make it from that super rubber , when you drop it on the floor it can bounce right back up in your hand .',
#    'UI Yeah .',
#    "ME You don't even need to lean down to get it .",
#    "UI The advantages of working with plastic and rubber is w we we'll have a lot more um options just in terms of shape",
#    'UI because you can extrude plastic in basically any shape you want .',
#    'UI So um and then we can cover you know the breakable bits with rubber yeah so um',
#    'PM Okay .',
#    'UI But basically these are curved and double-curved',
#    'UI I I believe that the tech department , in their um in their message to me , that they were referring to the number of th curves in the bottom .',
#    "UI I have no idea exactly what they're talking about ,",
#    "UI but that's what they told me , uncurved , flat , curved , or double-curved .",
#    'PM Okay .',
#    'UI I would guess this like this pen would be kinda like a double-curved ,',
#    "UI where it's curved on m m multiple axes , right ?",
#    'UI I think curved means just curved in one axis',
#    'UI and double-curved is curved in two axes',
#    'PM Okay .',
#    'UI or surfaces . I have no idea .',
#    'PM I think it might mean something like that sorta shape',
#    'PM because a double curve rather than a',
#    "ME Mm-hmm yeah that's yeah that's what I see .",
#    'UI Oh okay oh like a wave , okay .',
#    "PM yeah that's what .",
#    "ME Yeah that's what I see also .",
#    'UI Alright that makes sense okay .',
#    'UI Um okay , with the interface we have the following options ,',
#    'UI we can u we can use push buttons ,',
#    'UI we can use a scroll wheel with an integrated push button ,',
#    'UI and L_C_D_ display ,',
#    'ME Ooh .',
#    'UI or multiple scrolling wheels .',
#    'UI Um so these are all options that the user interface guy can uh has at his disposal to put together a user interface .',
#    'PM Okay .',
#    'UI For electronics , we have these very technical um descriptions here .',
#    'UI A simple chip , which is the least expensive ,',
#    'UI but I have no numbers to give you ,',
#    'UI a regular chip , which is like the medium porridge the medium expense uh',
#    'PM D do we have actually any concept of what the difference is between a simple chip and an advanced chip ?',
#    'UI Yes',
#    'UI the difference is , with a simple chip a simple chip will operate',
#    "UI oh why doesn't this scroll up ?",
#    'UI Previous previous , okay .',
#    'UI A simple chip is required to operate push buttons .',
#    'UI Um an advanced chip is required to to operate um the L_C_D_ display ,',
#    'PM Okay .',
#    "UI and it didn't say specifically , but I I have a hunch that a regular chip is gonna be the scroll wheel and the multiple scroll wheels .",
#    'PM Okay .',
#    'UI So but yeah .',
#    'PM Yeah that makes sense .',
#    "UI That's the end of my presentation .",
#    'PM So presentation from I guess design would go best . Next .',
#    'PM Technical functions or interface concept ?',
#    'UI I think',
#    'ID Oh interface concept .',
#    'ID Very long presentation .',
#    "PM Yeah that's it .",
#    'PM Yes , but it has your name on it .',
#    "ID Well that doesn't bo bode well for it for it tats as well .",
#    'ID Um so ,',
#    "ID somehow that thing's too big , but um",
#    'ID okay um',
#    'ID our uh manufacturing division wanted the speech recognition .',
#    'ID They say they could put it to work',
#    "ID but um we don't think so .",
#    'UI No .',
#    'ID No .',
#    "ID It it it you'll be you know be affected by the by the other speech and",
#    'UI If the T_V_ is working ,',
#    'UI yeah .',
#    "UI That's just",
#    "UI I mean it'll if somebody says up in the middle of a television show , it's gonna change the channel .",
#    'ID Yeah',
#    'ID and and fighting for the remote would not be fun anymore ,',
#    'UI So',
#    "ID and I think that's one of the things we wanna keep .",
#    'PM But what if you actually had to press a button to make it recognize ?',
#    'PM So if you pressed it and went , up ?',
#    'ID That kinda would r d',
#    "UI Well then why don't you just press the up button ?",
#    'ID yeah .',
#    'PM Man yeah .',
#    'ID That would kind of lose it .',
#    "PM But if it's just one thing with a button that you can just go",
#    "ME That's right .",
#    "UI Even still there's gonna be interf th there's there still will be interference from the T_V_ .",
#    'PM Up .',
#    'UI It might not be it might not be completely confusing ,',
#    'PM Yeah , okay .',
#    "UI but I think you'll still y it's still",
#    "UI I don't think it's practical at all .",
#    "UI I think it's a bad idea frankly .",
#    'ID Yeah so um taking that away , our uh the the the rubber but rubber buttons are the more reliable',
#    'PM Okay .',
#    'PM You guys know your stuff .',
#    "ID it's the the ones that would al would allow us to to market our product as being you know less prone to damage",
#    'ID and more resistant to things like spillage of liquids over it',
#    'ID or you know mistreat misuses as it happens to remote controls .',
#    'ID Um as for the point that we making about losing it .',
#    'ID Well , we wanna small r remote control one side',
#    'ID because uh we want it to be cool and uh designed ,',
#    'ID but um apparently um market shows that bigger s bigger um remotes get less lost ,',
#    'UI That I would believe .',
#    'ID about',
#    'ME Mm-hmm .',
#    'PM Mm .',
#    "ID But um yeah I think we we need to compromise between those two and somehow we'll do that . Somehow .",
#    'ID Um so the the what I would propose is something more or less in the uh direction of what is to yo the right of that slide uh',
#    'ID but without with a l a less complicated um design ,',
#    'ID so the numbers , the volume control , and channel control , and teletext access .',
#    'ID Uh the volume and channel control can just become those the the four button array as in if it was a round dial .',
#    'UI Mm-hmm .',
#    'ID And um if you just think about it as the one to the right but with the numbers and the four buttons plus maybe a centre one with teletext .',
#    "PM So we're suggesting doing a sorta scroll wheel thing for the volume ?",
#    "ID Ye no it's not",
#    "UI That's not a scroll wheel .",
#    "ID i i it's just four buttons that are on a cross ,",
#    'PM Nah .',
#    'PM Oh okay okay . I see .',
#    'ID so that you ba basically can control all of the important tasks from that alone .',
#    'UI Right .',
#    "UI Instead of play , stop , rewind , and fast forward there , that's up , down , louder , and quieter .",
#    'PM Uh , okay .',
#    'PM Okay .',
#    'ID Yeah',
#    'ID um yeah so I think we w we go for something mid-sized ,',
#    'ID so something looks good',
#    'ID and uh is not too prone to get lost .',
#    'ID That be it .',
#    "PM 'Kay .",
#    'PM So on to Y functional requirements or trend watching ?',
#    'ME I dunno .',
#    'UI Trend watching has a later date there .',
#    'ME Trend watching I guess .',
#    'ME Trend watching I believe .',
#    'PM forty six nineteen fifty seven . Yep .',
#    'ME See what it looks like .',
#    "ME It's been so long .",
#    'ID .',
#    "ME Well I don't know what to say .",
#    "ME When I s when I see the when I see the product I I I I don't wanna buy it .",
#    "ME I see so many of 'em out there .",
#    "ME There's nothing about that product that makes me wanna choose that product over other products that are out there .",
#    'UI Are you talking about the picture ?',
#    'ME Yeah yeah .',
#    "UI That's not our that's not our b design ,",
#    "UI that's just a that's just something he a a graphic he used to show you the layout of what the layout of the buttons might be like .",
#    'ME Okay .',
#    'ME Okay .',
#    "ME Okay 'cause 'cause right now I don't have too much to say about how to market this product",
#    "ME because we don't have a product to market yet .",
#    'ME And uh from from talking to Mike is that we have we have uh we can market a more expensive product now .',
#    'PM Mm .',
#    "ME That's what I understand so ,",
#    'PM Upper management said yes .',
#    'ME hello .',
#    "PM Uh e excuse that , that's a bit of spam .",
#    'ME And and so yeah',
#    "ME I'm a I'm a little bit stuck right now in that what uh w what is it that I'm gonna market ?",
#    "ME Uh without special or increased marketable features I don't believe the product has a consumer demand .",
#    'ME Uh I like the idea of of the scroll',
#    'ME makin',
#    'ME there are so many people making these products at this price right now .',
#    'ME What are we gonna do to make this one special and unique ?',
#    "UI What's special and unique about a scroll ?",
#    "ME Uh well I don't",
#    "PM It's cool .",
#    "ME yeah it's I I just see it as different .",
#    "ME I don't say it's specially mm",
#    "ME I don't say it's special .",
#    "ME Uh I say that it's different I",
#    "ME what I'm looking for as marketing is m give me something different .",
#    'ME I give me a lower price ,',
#    'ME give me a higher price ,',
#    'ME give me some new technology ,',
#    "ME don't give me the same thing that everybody else is putting out there on the shelf it's f at the same price .",
#    'ME I need something to market about this thing .',
#    "ME We're we're a new firm .",
#    "PM I'd I'd say though that we if we did make the decision to go with the cradle though , the then we have that as well ,",
#    'ME What i if when when we have',
#    'PM but wi with a similar',
#    'ME yeah',
#    "ME when we when we have something like the cradle or or something give that's",
#    'ME as as a marketing standard I need something to market , to make this product unique .',
#    'UI Well right I think the two big th points that we have so far are the having the cradle',
#    'UI and also having uh the um the actual design of the uh case itself having like this like rubber shell maybe with a plastic interior ,',
#    'ME Yep .',
#    'UI having it look really nice',
#    'UI um and also be really durable .',
#    "ME Mm 'kay .",
#    "ME Just remember when I made up this report I didn't have the information that we're discussing here .",
#    'UI Right yeah . Yeah .',
#    'PM Mm . Course .',
#    'ME And and so so uh yeah when we have a cradle , when we have some kind of design ,',
#    "ME so what I'm saying is , from my perspective , I don't have a product to market right now .",
#    'ME Um uh my personal preference is that we make some adjustment in the cost , either lower',
#    'ME or develop an integrated new technol technology .',
#    "ME That's that is the next step ,",
#    "ME there's technology and then there is technology , which we're moving into the next phase .",
#    "PM Yeah 'cause that's .",
#    "ME And so uh we're gonna have some new technology to enhance the marketability .",
#    "ME Yeah uh again I'm not sold on the product",
#    "ME because we don't have a product in my opinion yet .",
#    'PM Mm .',
#    'ME So I need a product .',
#    "PM Mm 'kay .",
#    "UI Well let's get a product then .",
#    'ME I need a product to market .',
#    "ME And I just whatever product you guys put together , we'll find a way to market it .",
#    "ME Tha that I'm not concerned with .",
#    'PM So now',
#    'ME If you if you give me if you give me a cut-out of what everybody else has then I need to I need to find a lower cost .',
#    'PM So our big questions here really are cradle or not cradle ?',
#    'PM Do we go basic or do we go for features ?',
#    'PM Uh d does anyone really wanna do anything with the scroll wheel or should we ditch that off-hand first ?',
#    'UI Well my question is what would the scroll wheel do ?',
#    'UI Function-wise , what does that do that',
#    'PM Oh but that was in your presentation',
#    'PM so wh what would you imagine it doing ?',
#    "ME Yeah wh wh what's the wh",
#    "UI Yeah . Well it's it's just another way to do the exact same thing that the buttons do .",
#    "PM Mm 'kay",
#    'ME Okay',
#    'ME now what I see with the scroll wheel is everybody has buttons .',
#    'ID But would we',
#    "ME So from a marketing standpoint I have I have another door to walk through when we have something that's unique .",
#    'PM Yeah .',
#    "ME If it creates something more complex or more expensive , then I don't know if that makes it uh a marketing necessity .",
#    'ME But again , from a marketing perspective I want as much new and different about this thing as possible',
#    "ME because we're we're co it's a very competitive market .",
#    "PM What I understand about scroll wheels is they're they're quite expensive to to make .",
#    'UI Yeah .',
#    'UI Th they are gonna be more expensive ,',
#    'PM So I d',
#    "UI but on the other hand , I mean , it I mean it is an alternative if if you think that's gonna sell some some uh you know",
# ...
#    "ME Whether it's a battery",
#    'ME it could be something really really minor , you know , like',
#    "ME but I think we are really keeping to what is already out there , and people've already seen it , people've already got it .",
#    'PM Okay .',
#    'ME If we want something new , we need to move away from what we already have',
#    'ME and um just go creative .',
#    'ID Maybe the kinetic mo provision of energy then .',
#    "ID It's been done for watches , but I haven't seen that for remotes , yet .",
#    "PM Okay . Yeah , this that's that's very good .",
#    'ME And then you can market it .',
#    'ME Never have to change a battery again .',
#    'ID Change the batteries ever again .',
#    'PM And and this is all tying in very nicely .',
#    "PM The fact that it's made out of this rubber , we can throw it about .",
#    'PM Th we should encourage people to throw their remote controls about , because it charges itself up by doing it .',
#    'ID Yeah ,',
#    'ID well , and in little characters you say , yeah , but not too much .',
#    'UI Yes , so can',
#    'ME I think , safety s',
#    'PM But yeah , by the squeezing it the',
#    'UI Yeah , we can make the squeezing of the rubber be the be the generating like the energy generator .',
#    "PM Yeah , that's a great idea . Well done .",
#    'ME Yeah .',
#    "ME Third most important aspect uh is it's easy to use .",
#    "UI we're all about that .",
#    "ME And I think we've all um worked that out .",
#    "ME Um okay , in the fashion , how it's supposed to look .",
#    "ME Next year's fashion i very much in fruit and vegetables are thm are like the theme for cloths , shoes and furniture .",
#    'ME So next year people will be buying ,',
#    'ME I found this really funny ,',
#    'ME you know , strawberry shaped chairs ,',
#    'UI Okay , so we could have keys that are like a b like a broccoli key and a uh and an avocado key on them .',
#    'PM Yeah .',
#    'ME Yeah .',
#    'ME Rubber things .',
#    'PM I wanna watch the pineapple channel .',
#    'ME Um',
#    "ME and as it's rubber the feel which is in this year is spongy ,",
#    "ME so it's it's not quite spongy , but spongy , I would say is",
#    'UI .',
#    "PM Well spongy , that's where .",
#    "PM Yeah , we're we're ahead of the game there .",
#    "UI Yeah , that's great for us .",
#    "ME yeah , so we're in .",
#    'ME Yeah .',
#    'ME And so personal what I was just saying like move away from the current remote controls uh like the look and the feel of the current ones and change the look and feel ,',
#    "ME while still keeping to the company's image , basically .",
#    'ME So yeah .',
#    'PM Okay .',
#    'ME . I had to say',
#    "ME So we're moving in the right direction like",
#    'UI Right .',
#    'PM Alright , yeah , no , this i this is good ,',
#    'UI Yeah .',
#    "PM so through all that we've we go we're",
#    "PM right , we're gonna go go back to um going with the kinetic thing ,",
#    'ID Yep .',
#    "UI Yeah , that's great .",
#    "PM that's great ,",
#    'PM using the spongy rubber that we were talking about',
#    'PM that anti-R_S_I_ you can as you squeeze it you are not only therapeuticising yourself , you are charging the batteries ,',
#    'ME Mm .',
#    "PM and um I'm not sure about the buttons being in the shape of fruit though .",
#    'ID No vegetables .',
#    "UI Yeah , I don't know how we incorporate",
#    'PM .',
#    "UI We don't have to follow every trend , I guess .",
#    'ME Maybe make it like fruity colours or something .',
#    'ME Some sort .',
#    'UI Uh-huh .',
#    'ME Or',
#    'UI The power button could be like a big apple or something .',
#    'ME Mm .',
#    'ID Well yeah , but Apple would sue you for that .',
#    'PM Yeah , this is true .',
#    "UI They don they don't own all images of apples .",
#    'ID sued the Beatles so',
#    "UI Okay , we'll make it a uh pomegranate , a big pomegranate .",
#    "PM Well , okay , it seems like the only thing that we haven't really finally um agreed on is its image .",
#    'UI .',
#    "PM Like , yeah , we're we're saying no we don't want it to be fruit and vegetables , but we dunno what it should be ,",
#    'PM or like are we going yeah it looks slick , but what do what do we mean by slick sort of thing ?',
#    'ME Well',
#    "ME I think , if it's rubber it needs to be",
#    'PM I mean you said earlier on i it should be funky .',
#    'ME different .',
#    "ME I think , it's it should be",
#    'ME I mean , what do you associate with rubber ?',
#    'ME You know like',
#    'PM L keep it clean , keep it clean .',
#    'ME really different colours basically .',
#    'ME Okay , sor I sorry , I used the wrong word ,',
#    'ME what do you associate with the mate the material that material ?',
#    'ME Um',
#    "ME Um like I'm just thinking bright colours .",
#    'UI Yeah .',
#    'ME Bright natural colours ,',
#    'ME nothing too',
#    'PM Bright , but not too bright .',
#    'ME Bright , but too not',
#    'ME yeah .',
#    'UI Yeah .',
#    'ME Like no lime green or bright yellow or bright pink .',
#    'ME Wanna make it different colours so anybody can choo like like',
#    'PM Like the volume buttons should be the all the same colour and the d and the the channel buttons should be one colour and stuff like that , do you mean ?',
#    'UI Mm .',
#    'ME Yeah .',
#    'ME And on the back of it have the logo .',
#    'PM Okay ,',
#    'PM what ?',
#    'ID Yeah .',
#    'UI Sure .',
#    'ID Why not ?',
#    'PM Okay .',
#    "UI The one thing I'm wondering about , I hope that we're not going like too much down a gimmicky road of of having",
#    'PM Tha',
#    'PM Yeah ,',
#    "PM I mean we that's we we",
#    "UI I mean if somebody go goes into the store they're gonna see like three or four normal remotes , and then a big spongy pink t tomato uh remote .",
#    'PM Yeah .',
#    'PM This is the remote control tomato .',
#    'UI I mean what are ninety per cent of people gonna take ?',
#    'ME Well',
#    "ME I can say in this country , you'll get , you know , lots of people wanting something really funky and cool .",
#    'ME Like',
#    'ME and kids will be walking in with their parents saying , Mummy I wanna buy that one .',
#    "ME And uh parents will see the will see the pro as well , because it's um",
#    "ME like kids won't break it , it's not breakable if you throw it around .",
#    'PM Yeah .',
#    'ME Especially with younger kids , you know they can pick it up and and',
#    'ME Yeah .',
#    'ME The only thing is is that really small kids might chew on it , but',
#    "PM Well , it's it's gotta be chew proof .",
#    'ME Yeah .',
#    'ME So',
#    "ID I'm gonna write that down .",
#    "ME so it's rea it's quite",
#    "ME it's quite like um user friendly",
#    'ME and also for different families , like like family use as well ,',
#    'ME so for little kids and for old ki like teenagers will like it , I think .',
#    "ME Especially maybe younger girls if it's in pink they'll be like pink remote control for their room something .",
#    'PM So , what are you saying , maybe we should market it in different colours for different',
#    'ME Yeah .',
#    'PM so we could do like the pink range , the blue range , the green range , the',
#    "ID That's yeah .",
#    'UI Mm .',
#    "ME So like you walk in , you're like , oh I like that remote control , because it's so bright , and then , and then the shop assistant comes up and says , oh what colour would you like ?",
#    'ME and then they go like , oh I can choose the colour wow .',
#    "ME So it puts , I think , even the customer into more control over what they're buying instead of , you've got all colour it's either that or nothing .",
#    'ME So they also get to pick .',
#    'ME Well , personally I like walking into a shop and choosing a colour .',
#    'UI Yeah I mean , that that seems to work well with for products like iPod ,',
#    "ME It's um",
#    "UI where , you know , you have a variety of colours , that people feel like they're customising it when they buy it , even , you know , just just by the fact of choosing .",
#    'ME Yeah .',
#    'PM Mm .',
#    'ME Mm .',
#    "ME D you've got the",
#    "ID Although I'd be curious to see how many uh",
#    'ID You know , there are some colours that I wouldn I would never choose , and I would be curious how many people choose that colour .',
#    'UI Right .',
#    "PM Well that's that can be down to bit of market researching you know ,",
#    'ID Mm .',
#    "PM if that's easy enough to find out what colours are more popular .",
#    'UI Yeah .',
#    'ID And produce less of the silly colours , maybe .',
#    'PM Mm .',
#    "PM Okay . Alright . Well um , we'll alright let's",
#    "PM what we're gonna aim to get together by the next meeting then um",
#    'PM is',
#    "PM from you Catherine wi your y y you know you're gonna be working on the the look and feel design .",
#    'ID Yep .',
#    "PM Um Gabriel , you're gonna be working on , you know come up with the the user interface design .",
#    'PM Then basically , you two are gonna be working together on this .',
#    "PM You won't be going off to your separate offices .",
#    'ID Alright .',
#    'UI Okay .',
#    'PM Um and I think you are gonna get a chance to play with some clay .',
#    'UI Oh right .',
#    "PM I think , yeah , it's gonna you know ,",
#    'ID Mm .',
#    'PM come up ki you know , be ab for the next meeting be able to come in and show us some some i some physical ideas .',
#    "PM 'Cause at the moment , uh you know , it's it's hard .",
#    'ID Cool .',
#    'UI Yeah .',
#    "PM We were kinda going , yeah , it's gotta feel nice , it's gotta look cool and that it's",
#    'ID It is .',
#    'PM you know now we can actually start ,',
#    'PM you know , s some sort of physical something or other .',
#    'UI That sounds good .',
#    "PM Um and you're gonna be working on the product evaluation .",
#    'ME Evaluation .',
#    'PM Um .',
#    'PM And I will be uh',
#    'PM talking to the bosses , basically , and uh',
#    'PM f fielding off some more spam and',
#    'PM uh',
#    'ID Great .',
#    "PM that's it really .",
#    'PM Keeping things t well ,',
#    'PM uh you know , ho hopefully uh keeping things together . Um .',
#    "PM Yeah , that's",
#    'PM This is this is uh good .',
#    "PM So we know for definite we know we've we've now got some definite things going on .",
#    "PM We definitely know how it's powered ,",
#    'UI Mm .',
#    "PM we definitely know that um it's gonna be a simple buttons ,",
#    "PM we're not gonna be going for the new technological chip on print expensive things , so we've we're keeping the costs down .",
#    "PM It's this rubber casing that we can sell as um fun and funky .",
#    "PM Don't know of any other remote controls that are made out of this stuff .",
#    'ME Mm .',
#    'PM People , you know , people are saying , oh , standard stuff gives you repetitive strain injury , well this remote control is designed to do the complete opposite ,',
#    'ME Yeah .',
#    "PM It's supposed to fix it rather than cause it . Um .",
#    "PM you know , we're gonna we",
#    "PM we're gonna as a sort of extra something on it ,",
#    'PM you know what what extra things are there extra things this product have ?',
#    "PM We'll look into this lock key",
#    'UI Right .',
#    'PM facility ,',
#    "PM although whether or not it happens , or is possible , I don't know ,",
#    'PM but something to look into .',
#    "PM Okay . I think that's um",
#    'PM well done everybody .',
#    'UI Alright .',
#    'PM Anyone have any uh any questions ,',
#    "PM everyone know what they're doing ?",
#    'UI Yeah .',
#    "PM 'Cause if you don't , you'll I'm sure you'll soon get an e-mail about it .",
#    'UI Yeah .',
#    'UI Mm , I think we all know what we need to do now .',
#    'ME S',
#    'ME This gives you all the details ?',
#    'PM Okay . right well .',
#    'UI Okay .',
#    "PM It's um we're we've still couple of minutes until our meeting's due to finish .",
#    'PM But um',
#    'PM I got a note saying that you two who are gonna be working together',
#    'PM so bef before you all disappear off just',
#    'UI Okay ,',
#    "UI I'll stay in here .",
#    'ME um .',
#    'PM hold hold fire . Um .',
#    'UI Does the pay-raise immediately come into effect on our next pay-check , or is that',
#    "PM Um I think , it's uh , yeah , I think , it's gonna be par part more of a profit sharing on the product .",
#    "UI So we're buying fut I mean , we're getting futures in the company .",
#    "PM Yeah , I think i I think that's I think that's the way it's gonna happen at the moment .",
#    'UI So we really have a incentive to make this remote work .',
#    'PM Yeah . Yeah .',
#    "UI I'd like to share in the coffee machine profits , because that's really doing well .",
#    'PM I want a share in the space rocket .',
#    "PM Did you see that this k that this company we've made a spaceship .",
#    'UI Yeah . .',
#    'ME Yeah .',
#    'UI This company has its its fingers in a lot of different pots .',
#    'PM Yeah .',
#    'PM Yeah .',
#    'ME Mm .',
#    "UI Yeah , we're definitely not in the money making department .",
#    'PM .',
#    'UI Well I I did notice looking at',
#    'UI I mean , they told you that they wanted whatev our product to represent the the R_R_ brand and and to be immediately noticeable .',
#    'PM Yeah .',
#    "UI I mean , if you look like at the coffee maker at the at the corporate web page , it's not obvious .",
#    'ME Mm .',
#    'UI R_R_ .',
#    'UI Well it is to us , because we we worked worked here for years and we use that coffee machine ,',
#    "UI but it's doesn't have the colour scheme of of the of the company anywhere on it obviously it's just sil silver and black .",
#    'PM Mm .',
#    "ID That's true .",
#    "PM And the spaceship doesn't have the R_ have a massive R_ and R_ down the side of it",
#    'UI No .',
#    "ID Doesn't",
#    'PM but I still want one .',
#    'UI Mm .',
#    "PM Okay . Um I've just had a sign flashing up saying , finish the meeting .",
#    'ID Yeah .',
#    'PM Uh .',
#    'UI Okay .',
#    'PM Yeah .',
#    "UI Right , well , I guess that's us .",
#    'PM Yeah .',
#    "PM It's not telling",
#    "PM it's not saying do anything in particular just yet .",
#    'PM So maybe you should go back to your own offices .',
#    'UI Okay . Right .',
#    'ID Are we taking these off ?',
#    'PM Yeah .',
#    'PM Yeah , it says you two'],
#   'summary_lines': ['@@abstract@@',
#    'The project manager recapped the decisions made in the previous meeting.',
#    'The industrial designer discussed different options for batteries, materials, and components, as well as restrictions involved in combining particular materials, components, and batteries.',
#    'The team then discussed and decided what materials, components, and what type of battery to use in their product.',
#    'The interface specialist presented examples of existing remotes on the market with good and bad layouts and stated what features the remote required.',
#    'The marketing expert discussed research from trendwatching reports, finding that products now require technological innovativeness, a fancy look and feel, a spongy feel, and a fruit and vegetable theme.',
#    'This lead to a discussion on whether to use Bluetooth or infra-red technology in remote.',
#    'The team then discussed how to incorporate a fruit and vegetable theme into the remote.',
#    '@@actions@@',
#    'The industrial designer will work on the look and feel of the design.',
#    'The interface specialist will work on the user interface design.',
#    'The industrial designer and the interface specialist will work on a prototype.',
#    'The marketing expert will work on the product evaluation',
#    '@@decisions@@',
#    'The case will be made of rubber.',
#    'The remote will have rubber push buttons.',
#    'The remote will not use a chip on print.',
#    'The case will be double curved.',
#    'There will be no display physically featured on the remote itself.',
#    'The remote will use a kinetic battery.',
#    '@@problems@@',
#    'Whether to have a sample sensor in the remote.',
#    'What color the remote should be.',
#    'Whether to use Bluetooth or infra-red technology in the remote.',
#    'How to incorporate a fruit and vegetable theme into the remote.']}]
