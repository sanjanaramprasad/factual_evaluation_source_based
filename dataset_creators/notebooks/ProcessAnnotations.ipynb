# %%
import psycopg2
import sqlalchemy
import pandas as pd

# %%
def update_stored_annotations(db_path):
    db_engine = sqlalchemy.create_engine(db_path)
    df = pd.read_sql_query("select * from label",con=db_engine)
    print('Annotations found', len(df))
    write_path = '/home/sanjana/factual_evaluation_source_based/annotations/round1_aggredialfact_annotated/dialoguefact_two_annotators_round1.csv'
    df.to_csv(write_path)
    return df

# %%
db_path = 'postgresql://sgqokpuggkrkve:ff59f8ca03f950cef2e98fb4ae4ff44bdf7136ff37da62215672902c613297d6@ec2-18-211-172-50.compute-1.amazonaws.com:5432/d3mhp3r7jhume9'
df = update_stored_annotations(db_path)
df
# Out:
# Annotations found 200
#                                      uuid   user_id     docid          model  \
# 0    b6273d21-9a0c-4033-8e2b-908d0a98c143   sanjana  13611370  gpt4-32k-0613
# 1    ec577599-01d2-4ed5-af77-245326c3ac8b  ann_ccry  13611370  gpt4-32k-0613
# 2    22a9198f-5a54-4d53-a630-552083d5b350  ann_ccry  13611426  gpt4-32k-0613
# 3    ef458bfe-4bef-430c-8d97-8efc30b21ded  ann_ccry  13611442  gpt4-32k-0613
# 4    e861c609-240f-416e-8a33-c0188daee831  ann_ccry  13611442  gpt4-32k-0613
# ..                                    ...       ...       ...            ...
# 195  8fd567ef-5cd3-4b87-9794-429a30c1455e  ann_ccry  13716129  gpt4-32k-0613
# 196  90e99f66-cbe7-447b-95c5-b4e04b615964  ann_ccry  13716129  gpt4-32k-0613
# 197  2f0a4478-851b-40c1-909a-5af2a292bf63  ann_ccry  13716169  gpt4-32k-0613
# 198  576ec558-4f6b-4736-9ef1-bb2ce813860f  ann_ccry  13716170  gpt4-32k-0613
# 199  8610c290-78a8-4de8-b5ff-e45396786740  ann_ccry  13716170  gpt4-32k-0613
#
# ...

# %%
df[~df['evidence'].isnull()]['evidence'].values[-1]
# Out:
# "Martha :  Hey, can I ask you a question?\nMartha :  Thanks!!! I'll check them  )\nOphelia :  No problem  )"

# %%
df[df['user_id'] == 'ann_wjbp']
# Out:
#                                      uuid   user_id     docid          model  \
# 6    660f2253-fa69-4881-9666-6a0d69ef9a2c  ann_wjbp  13611370  gpt4-32k-0613
# 7    650c80ed-35e6-4498-8314-6d8f0a85aa99  ann_wjbp  13611426  gpt4-32k-0613
# 8    195b4835-e3a9-459b-acd5-6f4b22ed539f  ann_wjbp  13611442  gpt4-32k-0613
# 9    02f228f5-435e-4906-bb98-1452bd51d708  ann_wjbp  13611508  gpt4-32k-0613
# 10   741ca003-607f-4dab-9173-e780ea38d9a9  ann_wjbp  13611832  gpt4-32k-0613
# ..                                    ...       ...       ...            ...
# 187  7106a8ec-6d2b-4a1b-b77e-cc89deab8141  ann_wjbp  13730730  gpt4-32k-0613
# 188  7d0b5775-dcbf-47dc-84d3-eecd0ec8763a  ann_wjbp  13730484  gpt4-32k-0613
# 189  6699ca78-7e26-4d74-b0e6-598405658c73  ann_wjbp  13730560  gpt4-32k-0613
# 190  49a77080-aaa0-4698-b247-ea03edc3c287  ann_wjbp  13730597  gpt4-32k-0613
# 191  49f02ebd-aefe-4783-ac88-c8185f71e170  ann_wjbp  13730771  gpt4-32k-0613
#
# ...
