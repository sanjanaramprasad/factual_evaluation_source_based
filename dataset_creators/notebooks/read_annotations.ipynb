# %%
import psycopg2
import sqlalchemy
import pandas as pd

# %%
db_engine = sqlalchemy.create_engine('postgresql://sgqokpuggkrkve:ff59f8ca03f950cef2e98fb4ae4ff44bdf7136ff37da62215672902c613297d6@ec2-18-211-172-50.compute-1.amazonaws.com:5432/d3mhp3r7jhume9')

# %%
df = pd.read_sql_query("select * from label",con=db_engine)
df
# Out:
#                                      uuid   user_id     docid          model  \
# 0    b8d502c5-1fa8-4b54-930b-8203eac9a9f9   sanjana  13611370  gpt4-32k-0613
# 1    47ff76cb-c241-435f-8e7f-c72db969bcaf   sanjana  13611426  gpt4-32k-0613
# 2    63d06a97-c9f1-490f-bbfd-4b4a0d5586f2   sanjana  13611442  gpt4-32k-0613
# 3    a65985ea-6cc5-414c-8112-81b45a9dca51   sanjana  13611508  gpt4-32k-0613
# 4    21546deb-2628-464e-b81c-208d7f3d432e   sanjana  13611559  gpt4-32k-0613
# ..                                    ...       ...       ...            ...
# 216  6e082568-67f7-4bcf-919a-2fccc0be3381   sanjana  13828511  gpt4-32k-0613
# 217  8a0f088f-adb1-4b01-9adb-42e93115bd0f  ann_kprt  13611370  gpt4-32k-0613
# 218  9f364d13-2041-4911-9c57-53d70e5ec04c  ann_kprt  13611426  gpt4-32k-0613
# 219  a7cb0324-122a-47f5-9754-86769760cc3d  ann_kprt  13611442  gpt4-32k-0613
# 220  2fcf9058-e7ad-41ae-babb-ef9a8eafd20a  ann_kprt  13611508  gpt4-32k-0613
#
#     nonfactual_spans evidence error_type  \
# ...

# %%
df_transformer = pd.read_csv('/home/sanjana/factual_evaluation_source_based/datasets/sota_annotations/dialogue_aggrefact.csv')

# %%
for idx, row in df_transformer.iterrows():
    if 'dick' in row['Dialogue']:
        print(row)
# Out:
# Unnamed: 0                                                     570
# DocID                                                     13727853
# Dialogue         Jen: I think I'm through with the dickhead. He...
# Model                                                    human_ref
# Summary          Jen is about to break up with her boyfriend. J...
# w/ Error                                                         0
# CorefE                                                         NaN
# CorefE_text                                                    NaN
# CircE                                                          NaN
# CircE_text                                                     NaN
# OutE                                                           NaN
# OutE_text                                                      NaN
# GramE                                                          NaN
# GramE_text                                                     NaN
# ...

# %%
df_transformer[~df_transformer['DocID'].isin(list(df['dialogue'].values))]
# Out:
#       Unnamed: 0     DocID                                           Dialogue  \
# 1186          36  13828456  Bailey: <file_other>\r\nBailey: ....\r\nMikael...
# 1187          37  13828456  Bailey: <file_other>\r\nBailey: ....\r\nMikael...
# 1188          38  13828456  Bailey: <file_other>\r\nBailey: ....\r\nMikael...
# 1189          39  13828456  Bailey: <file_other>\r\nBailey: ....\r\nMikael...
# 1202          52  13727579  Mum: hungry?\r\nSteve: starving...\r\nMum: I'l...
# ...          ...       ...                                                ...
# 1513         363  13829773  Ola: Hello Kate, sorry for not keeping in touc...
# 1518         368  13819472  Jenny: Are we going to that concert on Saturda...
# 1519         369  13819472  Jenny: Are we going to that concert on Saturda...
# 1520         370  13819472  Jenny: Are we going to that concert on Saturda...
# 1521         371  13819472  Jenny: Are we going to that concert on Saturda...
#
# ...

# %%
df_transformer
# Out:
#       Unnamed: 0     DocID                                           Dialogue  \
# 0              0  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 1              1  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 2              2  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 3              3  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# 4              4  13809941  Thelma: i dont have anything to wear\nLouisa: ...
# ...          ...       ...                                                ...
# 1545         395  13864835  Tony: <photo_file>\nAmy: Sweet little cat <3\n...
# 1546         396  13727934  Patricia: Hey, could you give me a call in an ...
# 1547         397  13727934  Patricia: Hey, could you give me a call in an ...
# 1548         398  13727934  Patricia: Hey, could you give me a call in an ...
# 1549         399  13727934  Patricia: Hey, could you give me a call in an ...
#
# ...

# %%
df_transformer = pd.read_csv('/home/sanjana/factual_evaluation_source_based/datasets/sota_annotations/dialogue_aggrefact.csv')

# %%
conn = psycopg2.connect(
   database="dd6goghvt02djh", 
    user='ppqbjimormsthy', 
    password='ef920ec6553ab7d225dbf61927f1c8ca28e002ce8ca6dbed67d31deb230ec7f0', 
    host='ec2-52-20-78-241.compute-1.amazonaws.com', 
    port = '5432'
    
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 conn = psycopg2.connect(
#       2    database="dd6goghvt02djh",
#       3     user='ppqbjimormsthy',
#       4     password='ef920ec6553ab7d225dbf61927f1c8ca28e002ce8ca6dbed67d31deb230ec7f0',
#       5     host='ec2-52-20-78-241.compute-1.amazonaws.com',
#       6     port = '5432'
#       7
#       8 )
#
# File /opt/conda/envs/eval_env/lib/python3.8/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# ...

# %%
cursor = conn.cursor()

sql_drop = '''DROP TABLE IF EXISTS generated_summaries;'''
cursor.execute(sql_drop)
conn.commit()

# %%
sql_drop = '''DROP TABLE IF EXISTS label;'''
cursor.execute(sql_drop)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 2
#       1 sql_drop = '''DROP TABLE IF EXISTS label;'''
# ----> 2 cursor.execute(sql_drop)
#       3 conn.commit()
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
# server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
