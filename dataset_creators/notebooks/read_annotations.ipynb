# %%
import psycopg2
import sqlalchemy
import pandas as pd

# %%
db_engine = sqlalchemy.create_engine('postgresql://sgqokpuggkrkve:ff59f8ca03f950cef2e98fb4ae4ff44bdf7136ff37da62215672902c613297d6@ec2-18-211-172-50.compute-1.amazonaws.com:5432/d3mhp3r7jhume9')

# %%
df = pd.read_sql_query("select * from label",con=db_engine)
df
# Out:
#                                      uuid   user_id     docid          model  \
# 0    b6273d21-9a0c-4033-8e2b-908d0a98c143   sanjana  13611370  gpt4-32k-0613
# 1    ec577599-01d2-4ed5-af77-245326c3ac8b  ann_ccry  13611370  gpt4-32k-0613
# 2    22a9198f-5a54-4d53-a630-552083d5b350  ann_ccry  13611426  gpt4-32k-0613
# 3    ef458bfe-4bef-430c-8d97-8efc30b21ded  ann_ccry  13611442  gpt4-32k-0613
# 4    e861c609-240f-416e-8a33-c0188daee831  ann_ccry  13611442  gpt4-32k-0613
# ..                                    ...       ...       ...            ...
# 460  6f41ae59-9c4a-44e6-aeff-52d24e0cc6ab  ann_wjbp   test_76  gpt4-32k-0613
# 461  0a4597a7-50d0-4386-8ab1-a522d33512fe  ann_wjbp   test_77  gpt4-32k-0613
# 462  b1ba3e05-0c27-4c4f-b48b-08b8a539dff1  ann_wjbp   test_90  gpt4-32k-0613
# 463  aaebcd3c-2ea4-4f29-acf0-a877a00a7f56  ann_wjbp   test_96  gpt4-32k-0613
# 464  0cb5ec42-93fc-4768-9fc3-e73b772b2f72  ann_wjbp   test_99  gpt4-32k-0613
#
#                                    nonfactual_spans               evidence  \
# 0                                              None                   None
# 1                                           lans to                  Maybe
# 2                                              both  principally the night
# 3                                              None                   None
# 4                                              None                   None
# ..                                              ...                    ...
# 460                                            None                   None
# 461                                            None                   None
# 462                                            None                   None
# 463  who Person2 is happy about having stood up to.              Not found
# 464                                            None                   None
#
#           error_type                                            summary  \
# 0               None  Derek asks Judy if she can feed his animals on...
# 1    Intrinsic_Error  Derek asks Judy if she can feed his animals on...
# 2    Intrinsic_Error  Poppy and Harry both prefer Lisbon, especially...
# 3               None  Helen was trying to reach Simon, but he was un...
# 4               None  Helen was trying to reach Simon, but he was un...
# ..               ...                                                ...
# 460             None  Person1 wanted to discuss sales projections fo...
# 461             None  Person1 is going to New York for the first tim...
# 462             None  Person1 and Person2 are planning for a picnic....
# 463  Extrinsic_Error  Person1 and Person2 are discussing Person2''s ...
# 464             None  Person1 recognizes Person2 and insists they kn...
#
#                                               dialogue
# 0    Derek: Judy, r you leaving for the weekend?\r\...
# 1    Derek: Judy, r you leaving for the weekend?\r\...
# 2    Poppy: Yeah. I definitely prefer Lisbon\r\nHar...
# 3    Helen: Hey, Simo, are you there?\r\nSimon: Yep...
# 4    Helen: Hey, Simo, are you there?\r\nSimon: Yep...
# ..                                                 ...
# 460  #Person1#: Hey there! I''ve been hoping to run...
# 461  #Person1#: I''m going to New York for the firs...
# 462  #Person1#: Mum, have we got any fruit to take ...
# 463  #Person1#: Bill, how can you hear so happy tod...
# 464  #Person1#: Hey, don''t I know you from somewhe...
#
# [465 rows x 9 columns]

# %%
df.to_csv('/home/sanjana/factual_evaluation_source_based/annotations/round1_aggredial_llm_annotated/db_dump_latest.csv')
