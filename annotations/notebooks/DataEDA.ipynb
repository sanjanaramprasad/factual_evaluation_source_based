# %%
import pandas as pd

# %%
df_sample = pd.read_csv('/home/ramprasad.sa/factual_evaluation_source_based/annotations/round1_aggredial_llm_annotated/second_annotator/qualifying_round/round2_sampletest.csv')

df_sample.head()[:1]
# Out:
#    Unnamed: 0                                  uuid  user_id     docid  \
# 0           0  4f078e37-1e86-425c-9770-db56cda00051  sanjana  13611734
#
#            model nonfactual_spans evidence error_type  \
# 0  gpt4-32k-0613              NaN      NaN        NaN
#
#                                              summary  \
# 0  Richie and Clay are discussing the performance...
#
#                                             dialogue
# 0  Richie: Pogba\r\nClay: Pogboom\r\nRichie: what...

# %%
df_sample
# Out:
#      Unnamed: 0                                  uuid   user_id     docid  \
# 0             0  4f078e37-1e86-425c-9770-db56cda00051   sanjana  13611734
# 1             1  1eea9cb1-0916-4547-91dc-808f342be3e9   sanjana  13716169
# 2             2  c8600806-0f6d-42d5-8960-b2b593ed06fc   sanjana  13716726
# 3             3  acfc3bb5-3614-49e4-9cca-a9cc04bb45e7   sanjana  13716905
# 4             4  b1778795-e25b-4268-b095-94b37310a59f   sanjana  13810193
# ..          ...                                   ...       ...       ...
# 103         103  8ffca760-8dc1-4025-a738-df11ab3b02e5  ann_lkji  13813011
# 104         104  01daee3c-968f-49b6-8bdc-30040d2688a4  ann_lkji  13819314
# 105         105  3dd35714-f368-43c8-9348-b8ad1f228e97  ann_lkji  13821034
# 106         106  2bbb5be7-1ce3-4278-8547-a4062862ee2c  ann_lkji  13821073
# 107         107  e93b9fe8-2657-4237-b86f-a525386f50f7  ann_lkji  13821297
#
#              model   nonfactual_spans   evidence       error_type  \
# ...

# %%
df_ann1 = pd.read_csv('/home/ramprasad.sa/factual_evaluation_source_based/annotations/round1_aggredial_llm_annotated/first_annotator/db_dump_latest.csv')

df_ann1.head()[:1]
# Out:
#    Unnamed: 0                                  uuid  user_id     docid  \
# 0           0  b6273d21-9a0c-4033-8e2b-908d0a98c143  sanjana  13611370
#
#            model nonfactual_spans evidence error_type  \
# 0  gpt4-32k-0613              NaN      NaN        NaN
#
#                                              summary  \
# 0  Derek asks Judy if she can feed his animals on...
#
#                                             dialogue
# 0  Derek: Judy, r you leaving for the weekend?\r\...

# %%
df_ann1 = df_ann1[df_ann1['user_id'] == 'ann_wjbp']
len(df_ann1)
# Out:
# 341

# %%
filter_ids  =  [str(each) for each in df_sample['docid'].values]
df_ann1_sample = df_ann1[df_ann1['docid'].isin(filter_ids)]
df_ann1_sample
# Out:
#      Unnamed: 0                                  uuid   user_id     docid  \
# 13           13  ae70ca0c-ff1e-4c9c-a23c-bceb18f80b1e  ann_wjbp  13611734
# 14           14  566d9748-4e07-4725-ba10-2126af84ec00  ann_wjbp  13611734
# 116         116  d52ff724-681b-4751-9048-83b525c10b8e  ann_wjbp  13716169
# 123         123  f222b93b-128e-4a29-b508-f43b207c0afb  ann_wjbp  13716726
# 127         127  09094a4b-ec87-4852-ab00-e729e67c52f9  ann_wjbp  13716905
# 226         226  1c40fa6f-a7a9-4c41-b024-81e9702a890d  ann_wjbp  13810193
# 232         232  2adf964f-4d39-471b-9ab8-d22aa3bdca5a  ann_wjbp  13813011
# 233         233  d07fe01e-5d90-4aae-b5f0-5c626f53c033  ann_wjbp  13813011
# 255         255  81fc5a46-9907-4a0f-8b47-42189eb0e881  ann_wjbp  13821034
# 256         256  9b765a42-41b6-4281-b4cc-24db212fce86  ann_wjbp  13819314
# 266         266  7cc7c4ac-56e0-4ece-926e-cc9aac5bcd29  ann_wjbp  13821073
# 268         268  b4568e89-7539-41d1-821a-224485c9b73e  ann_wjbp  13821297
#
# ...
